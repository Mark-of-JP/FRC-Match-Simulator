# %% [markdown]
# # Data Cleaning and Feature Engineering

# %% [markdown]
# by Mark JP Sanchez

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1.   Introduction
# 2.   Clean Up
# 3.   Feature Engineering
#   3.    i. Basic Features
#   3.    ii. Elo
#   3.    iii. Offensive Power Rating
#
# 4.   Creating the Use Case CSV
# 5.   Final Thoughts

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Now that we have all our data from the api, we need to focus on actually cleaning up our data and making some features for our use case. To start off we will be importing our basic packages:

# %%
#Set Up
import pandas as pd
import torch

if torch.cuda.is_available:
  print('GPU is available')
else:
  print('GPU is not available')
# Out:
# GPU is available

# %% [markdown]
# We are using two main packages for our data clean up and feature engineering. Pandas is the basic Python package used for Dataframes. We will be using this package to read and format our data for the use case.

# %% [markdown]
# Pytorch (torch) will be used later on for engineering some features. For features such as Offensive Power Rating (explained later), a lot of matrix operations are required and Pytorch comes with a lot of optimized functions for quick matrix manipulation. Pytorch also allows us to easily use a GPU to make our matrix manipulations even faster. The code was run on Google Colab so that I could make use of their free GPUs.

# %% [markdown]
# ## 2. Clean Up

# %% [markdown]
# To start off with our clean up, we need to actually read in the data we collected. Data collection code can be found in **data_collector.py**.

# %%
#Get the three dataframs
team_df = pd.read_csv('raw_frc_teams.csv')
match_df = pd.read_csv('raw_frc_matches.csv')
awards_df = pd.read_csv('raw_frc_awards.csv')

# %% [markdown]
# Now that we have our data, we can see that we have a lot of raw match data. While it might be useful to use all of the data we have at our disposal, it might be actually more detrimental than useful. One reason that using all our the data might be detrimental is the ever-changing nature of FIRST Robotics competitions. In the beginning, matches were played with two teams facing off two other teams. Modern day matches consists of a 3v3 match. Also, some of our features we are going to engineer requires us "simulate" the matches in chronological order and that is not possible for data that is missing the time component. Those that do have a time value, have their time value expressed in milliseconds which we will need to format for easier use. Those are just some of the few things we will need to remove and fix to clean up our data. The code below contains all the changes we did.

# %%
#Removal of rows and columns

#Remove unwanted columns
match_df = match_df.drop(columns=['Unnamed: 0', 'actual_time', 'predicted_time'])

#Remove rows that have matches that don't contain 3 teams per alliance
for i in range(3):
    match_df = match_df[match_df['red_' + str(i)].notna()]
    match_df = match_df[match_df['blue_' + str(i)].notna()]
    
#Remove rows that have no time or negative time
match_df = match_df[match_df['time'].notna()]
match_df = match_df.drop(match_df[match_df.time < 0].index)

#Remove rows that have no winners
match_df = match_df[match_df['winning_alliance'].notna()]

#Remove teams that are not found in team df
frc_team_keys = []
for index, row in team_df.iterrows():
    frc_team_keys.append(row['key'])
    
for i in range(3):
    match_df = match_df[match_df['red_' + str(i)].isin(frc_team_keys)]
    match_df = match_df[match_df['blue_' + str(i)].isin(frc_team_keys)]

#Change unix time to datetime
match_df['time'] = pd.to_datetime(match_df['time'], unit='s')
#Sort by time
match_df.sort_values(by='time', inplace=True)

#Get earliest years for awards and matches
earliest_award_year, earliest_match_year = 1992, 2016

#Add a year column since every year is a new game
match_df['year'] = match_df['time'].apply(lambda x : x.year)
#Data before 2014 is scarce
match_df = match_df[match_df['year'] >= earliest_match_year]

#Drop all nan
match_df = match_df.dropna()

#Reset the index
match_df = match_df.reset_index(drop=True)

# %% [markdown]
# ## 3. Feature Engineering

# %% [markdown]
# What is feature engineering and why do we do it?

# %% [markdown]
# Ultimately with this data, our goal is to create a prediction model to predict the winner of a given FIRST Robotics match. To create these models we need to feed it data which our model will base their predictions on. Our models will look at the different variables/features found within the data we feed it so we need to make sure that the features found within the data makes sense and help the model with its predictions. Sometimes it is useful to present data in a different way to help our models.

# %% [markdown]
# Be aware that not all features will be used for our models. We will explore the features more in depth in **FRC Match Simulator.ipynb** and see how they relate to each other. We might find out that some of our features are redundant or might actually make our models worse. We are only here to think up potentially useful features that covers all bases.

# %% [markdown]
# ### i. Basic Features

# %% [markdown]
# #### Games Played and Won

# %% [markdown]
# We will be counting the average number of games/matches played and won by each alliance in total and per season. We will get this feature by keeping track of how many games each team has played and won. We will then find the average number of games the teams in the alliance has won/played seperately and we will then average those results together. To help our model compare the average games played and won by each alliance we will create a variable that displays the difference between the averages of the red alliance and the blue alliance. Specifically for games won, we will calculate the average winrate of each alliance by find the difference between the averages. It is possible that an old team has a track record of losing a bunch of their matches so we need a feature that might reflect this.

# %% [markdown]
# #### Awards

# %% [markdown]
# FIRST Robotics hands out a lot of awards during their competitions for a multitude of reasons. Some awards pertain to the matches the teams played while others pertain to things such as safety and engineering capabilities of the team. Since there are different types of awards we will split them into two categories: Match Awards which pertain to awards that are given to those that do well in matches and Other Awards which are all the other awards. We will find the average number of awards each alliance has and we will get the difference between the averages.

# %% [markdown]
# #### Age

# %% [markdown]
# This is mostly self-explanatory. We will find the difference between the average age of the blue alliance and the red alliance. Intuitively, older teams will know how to build better robots and older teams will probably have more sponsors since they had more time to find them.

# %% [markdown]
# #### Points

# %% [markdown]
# Same as the features above, we will be finding the average number of points each alliance gets per season. We will not however be finding the difference between the averages. Since every season is a different game, the average point values for each game differs as well. Some games see an average for 150 points while others see an average of 2000. So instead of finding the difference between the averages we will divide the average of points scored of the red alliance by the average points scored of the blue alliance: $red\_points\_ratio =\frac {red\ points} {blue\ points}$. In cases where not all member of an alliance have played at least 1 game, we will say the ratio between the two teams is 1 so that the models believes two teams are equal if they have very little data on them. This way if the red alliance scores double the amount of points the blue alliance scores, we have a metric that reflects this no matter what the season

# %% [markdown]
# ### ii. ELO

# %% [markdown]
# ELO is a rating system that has been used in many games and originated from the game of chess. The elo system works by giving every person a number/elo value which designates their rank or their skill value. Winning against someone with a higher elo value than you increases your elo value by a large margin and decreases their elo value by a large margin. Winning against someone with a lower elo value than you increase your elo value by a small margin and decreases their elo value by a small margin. To create an elo system works by arbitrarily choosing a number to be your baseline rank which you will give to every new team. Our baseline rank will be the standard number of 1500. The elo system also has a formula which predicts the likely hood of a person winning a match and that is the value we will be using for our models.

# %% [markdown]
# The reason why we are using the elo ranking system is because it assigns a sort of skill value for each team based on their wins and losses. Good new teams can be recognized by the models when they start winning against teams with high elo values. The elo system also gives more context to each win and loss a team receives. A team that got lucky and only competes against low elo teams might have the same winrate as a team that competes against a lot of high elo teams. The elo system ensures that the models don't see these two teams to be equal in skill.

# %% [markdown]
# Formula for elo value change (*elo_result: 1 if player won and 0 if player lost*): $elo = old\_elo + 10*(elo\_result - elo\_prediction)$

# %% [markdown]
# Formula for elo prediction: $prediction = \frac {1} {1 + 10^{(red\_elo - blue\_elo)/400}}$

# %% [markdown]
# For more information on the elo ranking system check here: https://en.wikipedia.org/wiki/Elo_rating_system

# %% [markdown]
# *Note: The code below engineers all of the above features.*

# %%
#Format proper data and extract new data 

#Change winning alliance to red win
match_df['red_won'] = 0
match_df.loc[match_df['winning_alliance'] == 'red', 'red_won'] = 1

#Get Average Data
team_data = {}

#Adds a team to team data and initializes its default values
def initialize_team(team_key):
    team_data[team_key] = {}
    
    #Initialize awards
    team_data[team_key]['match_awards'] = 0
    team_data[team_key]['other_awards'] = 0
    
    #Initialize games
    team_data[team_key]['games_played'] = 0
    team_data[team_key]['games_won'] = 0
    
    team_data[team_key]['games_played_season'] = 0
    team_data[team_key]['games_won_season'] = 0
    team_data[team_key]['points_season'] = 0
    
    team_data[team_key]['elo'] = 1500
    
    team_data[team_key]['rookie_year'] = team_df[team_df['key'] == team_key]['rookie_year'].item()
    
#Adds awards to team from a certain event
def add_event_awards(event_key):
    if event_key is None:
        return
    
    event_awards_df = awards_df[awards_df['event_key'] == event_key]
    
    for index, row in event_awards_df.iterrows():
        team_key = row['recipient']
        
        if team_key not in team_data:
            initialize_team(team_key)
            
        if row['award_type'] in match_award_types:
            team_data[team_key]['match_awards'] += 1
        else:
            team_data[team_key]['other_awards'] += 1
        

#Get initial award data
#Splitting the awards into match awards and other awards
#Award types can be found here: https://github.com/the-blue-alliance/the-blue-alliance/blob/master/consts/award_type.py#L15
match_award_types = [0, 1, 2, 10, 14]
    
print('Initializing initial awards...')
for year in range(earliest_award_year, earliest_match_year):
    print('Formatting awards for the year ' + str(year))
    year_award_df = awards_df[awards_df['year'] == year]
    
    for index, row in year_award_df.iterrows():
        team_key = row['recipient']
        
        if team_key not in team_data:
            initialize_team(team_key)
            
        if row['award_type'] in match_award_types:
            team_data[team_key]['match_awards'] += 1
        else:
            team_data[team_key]['other_awards'] += 1
            
#Stores number of matches for giving awards from events
print("Recording number of matches per event")
num_of_matches_per_event = {}
event_groupby = match_df.groupby('event_key')
for event_key, group in event_groupby:
    num_of_matches_per_event[event_key] = len(match_df[match_df.event_key == event_key])
            
#Adding team data to matches dataframe
print('Adding team data to matches...')
match_df['red_avg_match_awards'] = 0
match_df['red_avg_other_awards'] = 0

match_df['blue_avg_match_awards'] = 0
match_df['blue_avg_other_awards'] = 0

match_df['red_avg_winrate'] = 0
match_df['red_avg_games_played'] = 0

match_df['blue_avg_winrate'] = 0
match_df['blue_avg_games_played'] = 0

match_df['red_avg_age'] = 0
match_df['blue_avg_age'] = 0

match_df['red_points_ratio_season'] = 0
match_df['red_points_avg'] = 0
match_df['red_avg_winrate_season'] = 0
match_df['red_avg_games_played_season'] = 0
match_df['blue_points_avg'] = 0
match_df['blue_avg_winrate_season'] = 0
match_df['blue_avg_games_played_season'] = 0

match_df['red_elo'] = 0
match_df['blue_elo'] = 0
match_df['elo_prediction'] = 0

#Functions for formatting data
def get_avg_awards(alliance):
    total_match_awards = 0.0
    total_other_awards = 0.0
    
    for team_key in alliance:
        total_match_awards += team_data[team_key]['match_awards']
        total_other_awards += team_data[team_key]['other_awards']
        
    return total_match_awards / len(alliance), total_other_awards / len(alliance)

def get_avg_games(alliance, boundary=''):
    total_games_played = 0
    total_wins = 0
    
    for team_key in alliance:
        total_games_played += team_data[team_key]['games_played' + boundary]
        total_wins += team_data[team_key]['games_won' + boundary]
        
    winrate = 0.5 if total_games_played == 0 else total_wins / total_games_played
        
    return total_games_played / len(alliance), winrate

def get_avg_age(alliance, current_year):
    total_age = 0
    
    for team_key in alliance:
        total_age += current_year - team_data[team_key]['rookie_year']
        
    return total_age / len(alliance)

def get_red_points_ratio(red_avg, blue_avg):
    
    if red_avg == -1 or blue_avg == -1:
        return 1
    
    return red_avg / blue_avg

def get_points_avg(alliance, boundary='_season'):
    total_avgs = 0
    
    for team_key in alliance:
        if team_data[team_key]['games_played' + boundary] == 0:
            return -1
        
        total_avgs += (team_data[team_key]['points' + boundary] / team_data[team_key]['games_played' + boundary])
        
    return total_avgs / len(alliance)

def get_elo_average(alliance):
    total_elo = 0
    
    for team_key in alliance:
        total_elo += team_data[team_key]['elo']
        
    return total_elo / len(alliance)

def get_elo_prediction(red_alliance_elo, blue_alliance_elo):
    elo_delta = blue_alliance_elo - red_alliance_elo
    
    return 1 / (1 + (10**(elo_delta / 400)))

def change_elo(alliance, prediction, result):
    for team_key in alliance:
        team_data[team_key]['elo'] += 10 * (result - prediction)

def reset_season():
    
    for team_key in team_data:
        team_data[team_key]['games_played'] += team_data[team_key]['games_played_season']
        team_data[team_key]['games_won'] += team_data[team_key]['games_won_season']
        
        team_data[team_key]['games_played_season'] = 0
        team_data[team_key]['games_won_season'] = 0
        team_data[team_key]['points_season'] = 0

#Set up variables for iteration through the matches
curr_year = None
len_match = len(match_df)
match_df = match_df.reset_index(drop=True)
#Iterate/simulate each match
for index, row in match_df.iterrows():
    
    print('Engineering features for match ' + str(index) + "/" + str(len_match))
    
    if row['year'] != curr_year:
        curr_year = row['year']
        reset_season()
        
    #Get the red and blue alliance
    red_alliance = [row['red_0'], row['red_1'], row['red_2']]
    blue_alliance = [row['blue_0'], row['blue_1'], row['blue_2']]
    
    #Initialize the teams
    for i in range(3):
        if red_alliance[i] not in team_data:
            initialize_team(red_alliance[i])
        if blue_alliance[i] not in team_data:
            initialize_team(blue_alliance[i])
        
    #Add data to the datafram
    row['red_avg_match_awards'], row['red_avg_other_awards'] = get_avg_awards(red_alliance)
    row['blue_avg_match_awards'], row['blue_avg_other_awards'] = get_avg_awards(blue_alliance)
    
    row['red_avg_games_played'], row['red_avg_winrate'] = get_avg_games(red_alliance)
    row['blue_avg_games_played'], row['blue_avg_winrate'] = get_avg_games(blue_alliance)
    
    row['red_avg_games_played_season'], row['red_avg_winrate_season'] = get_avg_games(red_alliance, boundary='_season')
    row['blue_avg_games_played_season'], row['blue_avg_winrate_season'] = get_avg_games(blue_alliance, boundary='_season')
    
    row['red_points_avg'] = get_points_avg(red_alliance)
    row['blue_points_avg'] = get_points_avg(blue_alliance)
    row['red_points_ratio_season'] = get_red_points_ratio(row['red_points_avg'], row['blue_points_avg'])
    
    row['red_avg_age'] = get_avg_age(red_alliance, row['time'].year)
    row['blue_avg_age'] = get_avg_age(blue_alliance, row['time'].year)
    
    row['red_elo'] = get_elo_average(red_alliance)
    row['blue_elo'] = get_elo_average(blue_alliance)
    
    red_pred = get_elo_prediction(row['red_elo'], row['blue_elo'])
    blue_pred = get_elo_prediction(row['blue_elo'], row['red_elo'])
    
    row['elo_prediction'] = red_pred
    
    #Add match stats to the teams
    if row['red_won'] == 1:
        for team_key in red_alliance:
            team_data[team_key]['games_won_season'] += 1
            
        change_elo(red_alliance, red_pred, 1)
        change_elo(blue_alliance, blue_pred, 0)
    else:
        for team_key in blue_alliance:
            team_data[team_key]['games_won_season'] += 1
            
        change_elo(red_alliance, red_pred, 0)
        change_elo(blue_alliance, blue_pred, 1)
            
    for team_key in (blue_alliance + red_alliance):
        team_data[team_key]['games_played_season'] += 1
       
    for team_key in red_alliance:
        team_data[team_key]['points_season'] += row['red_score']
        
    for team_key in blue_alliance:
        team_data[team_key]['points_season'] += row['red_score']
        
    #Add new event awards if previous event has passed
    num_of_matches_per_event[row['event_key']] -= 1
    if num_of_matches_per_event[row['event_key']] <= 0:
        add_event_awards(row['event_key'])
        # reset_match(row['event_key'])
    
    match_df.loc[index] = row
    
#Get differences for the features that require differences
match_df['avg_match_awards_diff'] = match_df['red_avg_match_awards'] - match_df['blue_avg_match_awards']
match_df['avg_other_awards_diff'] = match_df['red_avg_other_awards'] - match_df['blue_avg_other_awards']
match_df['avg_winrate_diff'] = match_df['red_avg_winrate'] - match_df['blue_avg_winrate']
match_df['avg_games_played_diff'] = match_df['red_avg_games_played'] - match_df['blue_avg_games_played']
match_df['avg_age_diff'] = match_df['red_avg_age'] - match_df['blue_avg_age']
match_df['avg_winrate_diff_season'] = match_df['red_avg_winrate_season'] - match_df['blue_avg_winrate_season']
match_df['avg_games_played_diff_season'] = match_df['red_avg_games_played_season'] - match_df['blue_avg_games_played_season']
# Out:
# Streaming output truncated to the last 5000 lines.
# Engineering features for match 67792/72791
# Engineering features for match 67793/72791
# Engineering features for match 67794/72791
# Engineering features for match 67795/72791
# Engineering features for match 67796/72791
# Engineering features for match 67797/72791
# Engineering features for match 67798/72791
# Engineering features for match 67799/72791
# Engineering features for match 67800/72791
# Engineering features for match 67801/72791
# Engineering features for match 67802/72791
# Engineering features for match 67803/72791
# Engineering features for match 67804/72791
# Engineering features for match 67805/72791
# Engineering features for match 67806/72791
# Engineering features for match 67807/72791
# Engineering features for match 67808/72791
# Engineering features for match 67809/72791
# Engineering features for match 67810/72791
# Engineering features for match 67811/72791
# Engineering features for match 67812/72791
# Engineering features for match 67813/72791
# Engineering features for match 67814/72791
# Engineering features for match 67815/72791
# Engineering features for match 72454/72791
# Engineering features for match 72455/72791
# Engineering features for match 72456/72791
# Engineering features for match 72457/72791
# Engineering features for match 72458/72791
# Engineering features for match 72459/72791
# Engineering features for match 72460/72791
# Engineering features for match 72461/72791
# Engineering features for match 72462/72791
# Engineering features for match 72463/72791
# Engineering features for match 72464/72791
# Engineering features for match 72465/72791
# Engineering features for match 72466/72791
# Engineering features for match 72467/72791
# Engineering features for match 72468/72791
# Engineering features for match 72469/72791
# Engineering features for match 72470/72791
# Engineering features for match 72471/72791
# Engineering features for match 72472/72791
# Engineering features for match 72473/72791
# Engineering features for match 72474/72791
# Engineering features for match 72475/72791
# Engineering features for match 72476/72791
# Engineering features for match 72477/72791
# Engineering features for match 72478/72791
# Engineering features for match 72479/72791
# Engineering features for match 72480/72791
# Engineering features for match 72481/72791
# Engineering features for match 72482/72791
# Engineering features for match 72483/72791
# Engineering features for match 72484/72791
# Engineering features for match 72485/72791
# Engineering features for match 72486/72791
# Engineering features for match 72487/72791
# Engineering features for match 72488/72791
# Engineering features for match 72489/72791
# Engineering features for match 72490/72791
# Engineering features for match 72491/72791
# Engineering features for match 72492/72791
# Engineering features for match 72493/72791
# Engineering features for match 72494/72791
# Engineering features for match 72495/72791
# Engineering features for match 72496/72791
# Engineering features for match 72497/72791
# Engineering features for match 72498/72791
# Engineering features for match 72499/72791
# Engineering features for match 72500/72791
# Engineering features for match 72501/72791
# Engineering features for match 72502/72791
# Engineering features for match 72503/72791
# Engineering features for match 72504/72791
# Engineering features for match 72505/72791
# Engineering features for match 72506/72791
# Engineering features for match 72507/72791
# Engineering features for match 72508/72791
# Engineering features for match 72509/72791
# Engineering features for match 72510/72791
# Engineering features for match 72511/72791
# Engineering features for match 72512/72791
# Engineering features for match 72513/72791
# Engineering features for match 72514/72791
# Engineering features for match 72515/72791
# Engineering features for match 72516/72791
# Engineering features for match 72517/72791
# Engineering features for match 72518/72791
# Engineering features for match 72519/72791
# Engineering features for match 72520/72791
# Engineering features for match 72521/72791
# Engineering features for match 72522/72791
# Engineering features for match 72523/72791
# Engineering features for match 72524/72791
# Engineering features for match 72525/72791
# Engineering features for match 72526/72791
# Engineering features for match 72527/72791
# Engineering features for match 72528/72791
# Engineering features for match 72529/72791
# Engineering features for match 72530/72791
# Engineering features for match 72531/72791
# Engineering features for match 72532/72791
# Engineering features for match 72533/72791
# Engineering features for match 72534/72791
# Engineering features for match 72535/72791
# Engineering features for match 72536/72791
# Engineering features for match 72537/72791
# Engineering features for match 72538/72791
# Engineering features for match 72539/72791
# Engineering features for match 72540/72791
# Engineering features for match 72541/72791
# Engineering features for match 72542/72791
# Engineering features for match 72543/72791
# Engineering features for match 72544/72791
# Engineering features for match 72545/72791
# Engineering features for match 72546/72791
# Engineering features for match 72547/72791
# Engineering features for match 72548/72791
# Engineering features for match 72549/72791
# Engineering features for match 72550/72791
# Engineering features for match 72551/72791
# Engineering features for match 72552/72791
# Engineering features for match 72553/72791
# Engineering features for match 72554/72791
# Engineering features for match 72555/72791
# Engineering features for match 72556/72791
# Engineering features for match 72557/72791
# Engineering features for match 72558/72791
# Engineering features for match 72559/72791
# Engineering features for match 72560/72791
# Engineering features for match 72561/72791
# Engineering features for match 72562/72791
# Engineering features for match 72563/72791
# Engineering features for match 72564/72791
# Engineering features for match 72565/72791
# Engineering features for match 72566/72791
# Engineering features for match 72567/72791
# Engineering features for match 72568/72791
# Engineering features for match 72569/72791
# Engineering features for match 72570/72791
# Engineering features for match 72571/72791
# Engineering features for match 72572/72791
# Engineering features for match 72573/72791
# Engineering features for match 72574/72791
# Engineering features for match 72575/72791
# Engineering features for match 72576/72791
# Engineering features for match 72577/72791
# Engineering features for match 72578/72791
# Engineering features for match 72579/72791
# Engineering features for match 72580/72791
# Engineering features for match 72581/72791
# Engineering features for match 72582/72791
# Engineering features for match 72583/72791
# Engineering features for match 72584/72791
# Engineering features for match 72585/72791
# Engineering features for match 72586/72791
# Engineering features for match 72587/72791
# Engineering features for match 72588/72791
# Engineering features for match 72589/72791
# Engineering features for match 72590/72791
# Engineering features for match 72591/72791
# Engineering features for match 72592/72791
# Engineering features for match 72593/72791
# Engineering features for match 72594/72791
# Engineering features for match 72595/72791
# Engineering features for match 72596/72791
# Engineering features for match 72597/72791
# Engineering features for match 72598/72791
# Engineering features for match 72599/72791
# Engineering features for match 72600/72791
# Engineering features for match 72601/72791
# Engineering features for match 72602/72791
# Engineering features for match 72603/72791
# Engineering features for match 72604/72791
# Engineering features for match 72605/72791
# Engineering features for match 72606/72791
# Engineering features for match 72607/72791
# Engineering features for match 72608/72791
# Engineering features for match 72609/72791
# Engineering features for match 72610/72791
# Engineering features for match 72611/72791
# Engineering features for match 72612/72791
# Engineering features for match 72613/72791
# Engineering features for match 72614/72791
# Engineering features for match 72615/72791
# Engineering features for match 72616/72791
# Engineering features for match 72617/72791
# Engineering features for match 72618/72791
# Engineering features for match 72619/72791
# Engineering features for match 72620/72791
# Engineering features for match 72621/72791
# Engineering features for match 72622/72791
# Engineering features for match 72623/72791
# Engineering features for match 72624/72791
# Engineering features for match 72625/72791
# Engineering features for match 72626/72791
# Engineering features for match 72627/72791
# Engineering features for match 72628/72791
# Engineering features for match 72629/72791
# Engineering features for match 72630/72791
# Engineering features for match 72631/72791
# Engineering features for match 72632/72791
# Engineering features for match 72633/72791
# Engineering features for match 72634/72791
# Engineering features for match 72635/72791
# Engineering features for match 72636/72791
# Engineering features for match 72637/72791
# Engineering features for match 72638/72791
# Engineering features for match 72639/72791
# Engineering features for match 72640/72791
# Engineering features for match 72641/72791
# Engineering features for match 72642/72791
# Engineering features for match 72643/72791
# Engineering features for match 72644/72791
# Engineering features for match 72645/72791
# Engineering features for match 72646/72791
# Engineering features for match 72647/72791
# Engineering features for match 72648/72791
# Engineering features for match 72649/72791
# Engineering features for match 72650/72791
# Engineering features for match 72651/72791
# Engineering features for match 72652/72791
# Engineering features for match 72653/72791
# Engineering features for match 72654/72791
# Engineering features for match 72655/72791
# Engineering features for match 72656/72791
# Engineering features for match 72657/72791
# Engineering features for match 72658/72791
# Engineering features for match 72659/72791
# Engineering features for match 72660/72791
# Engineering features for match 72661/72791
# Engineering features for match 72662/72791
# Engineering features for match 72663/72791
# Engineering features for match 72664/72791
# Engineering features for match 72665/72791
# Engineering features for match 72666/72791
# Engineering features for match 72667/72791
# Engineering features for match 72668/72791
# Engineering features for match 72669/72791
# Engineering features for match 72670/72791
# Engineering features for match 72671/72791
# Engineering features for match 72672/72791
# Engineering features for match 72673/72791
# Engineering features for match 72674/72791
# Engineering features for match 72675/72791
# Engineering features for match 72676/72791
# Engineering features for match 72677/72791
# Engineering features for match 72678/72791
# Engineering features for match 72679/72791
# Engineering features for match 72680/72791
# Engineering features for match 72681/72791
# Engineering features for match 72682/72791
# Engineering features for match 72683/72791
# Engineering features for match 72684/72791
# Engineering features for match 72685/72791
# Engineering features for match 72686/72791
# Engineering features for match 72687/72791
# Engineering features for match 72688/72791
# Engineering features for match 72689/72791
# Engineering features for match 72690/72791
# Engineering features for match 72691/72791
# Engineering features for match 72692/72791
# Engineering features for match 72693/72791
# Engineering features for match 72694/72791
# Engineering features for match 72695/72791
# Engineering features for match 72696/72791
# Engineering features for match 72697/72791
# Engineering features for match 72698/72791
# Engineering features for match 72699/72791
# Engineering features for match 72700/72791
# Engineering features for match 72701/72791
# Engineering features for match 72702/72791
# Engineering features for match 72703/72791
# Engineering features for match 72704/72791
# Engineering features for match 72705/72791
# Engineering features for match 72706/72791
# Engineering features for match 72707/72791
# Engineering features for match 72708/72791
# Engineering features for match 72709/72791
# Engineering features for match 72710/72791
# Engineering features for match 72711/72791
# Engineering features for match 72712/72791
# Engineering features for match 72713/72791
# Engineering features for match 72714/72791
# Engineering features for match 72715/72791
# Engineering features for match 72716/72791
# Engineering features for match 72717/72791
# Engineering features for match 72718/72791
# Engineering features for match 72719/72791
# Engineering features for match 72720/72791
# Engineering features for match 72721/72791
# Engineering features for match 72722/72791
# Engineering features for match 72723/72791
# Engineering features for match 72724/72791
# Engineering features for match 72725/72791
# Engineering features for match 72726/72791
# Engineering features for match 72727/72791
# Engineering features for match 72728/72791
# Engineering features for match 72729/72791
# Engineering features for match 72730/72791
# Engineering features for match 72731/72791
# Engineering features for match 72732/72791
# Engineering features for match 72733/72791
# Engineering features for match 72734/72791
# Engineering features for match 72735/72791
# Engineering features for match 72736/72791
# Engineering features for match 72737/72791
# Engineering features for match 72738/72791
# Engineering features for match 72739/72791
# Engineering features for match 72740/72791
# Engineering features for match 72741/72791
# Engineering features for match 72742/72791
# Engineering features for match 72743/72791
# Engineering features for match 72744/72791
# Engineering features for match 72745/72791
# Engineering features for match 72746/72791
# Engineering features for match 72747/72791
# Engineering features for match 72748/72791
# Engineering features for match 72749/72791
# Engineering features for match 72750/72791
# Engineering features for match 72751/72791
# Engineering features for match 72752/72791
# Engineering features for match 72753/72791
# Engineering features for match 72754/72791
# Engineering features for match 72755/72791
# Engineering features for match 72756/72791
# Engineering features for match 72757/72791
# Engineering features for match 72758/72791
# Engineering features for match 72759/72791
# Engineering features for match 72760/72791
# Engineering features for match 72761/72791
# Engineering features for match 72762/72791
# Engineering features for match 72763/72791
# Engineering features for match 72764/72791
# Engineering features for match 72765/72791
# Engineering features for match 72766/72791
# Engineering features for match 72767/72791
# Engineering features for match 72768/72791
# Engineering features for match 72769/72791
# Engineering features for match 72770/72791
# Engineering features for match 72771/72791
# Engineering features for match 72772/72791
# Engineering features for match 72773/72791
# Engineering features for match 72774/72791
# Engineering features for match 72775/72791
# Engineering features for match 72776/72791
# Engineering features for match 72777/72791
# Engineering features for match 72778/72791
# Engineering features for match 72779/72791
# Engineering features for match 72780/72791
# Engineering features for match 72781/72791
# Engineering features for match 72782/72791
# Engineering features for match 72783/72791
# Engineering features for match 72784/72791
# Engineering features for match 72785/72791
# Engineering features for match 72786/72791
# Engineering features for match 72787/72791
# Engineering features for match 72788/72791
# Engineering features for match 72789/72791
# Engineering features for match 72790/72791

# %% [markdown]
# ### iii. Offensive Power Rating (OPR)

# %% [markdown]
# The Offensive Power Rating (OPR) system has been used by a couple of FIRST Robotics team as a way to gauge a team's skill. Each team is assigned an OPR value which is calculated from their previous matches. The OPR of a team is the predicted number of points they are going to contribute in a match. So the sum of all the OPR values in an alliance is the predicted points they will earn for that match. Here is how we find a team's OPR:

# %% [markdown]
# Assume that instead of 3 teams per alliance there are 2 teams per alliance. Also assume that every team will contribute the same number of points per match. Let **A**, **B**, and **C** be the number of points team A, B and C will contribute, respectively. Let's say team A and B play a match together where they score 40 points. So the equation for that match would be: $A + B = 40$. A few more matches occur and these are the equations that pertain to all the matches.

# %% [markdown]
# $A+B=40$

# %% [markdown]
# $B+C=35$

# %% [markdown]
# $A+C=20$

# %% [markdown]
# As we can see, the matches are just a system of linear equation and so we can solve for **A**, **B** and **C**. Well A, B and C are the OPR values for Team A, B and C. Since it is just a system of linear equations we can easily turn it into an $Ax=B$ matrix equation which we can use Pytorch to solve.

# %% [markdown]
# There are caveats to this system. For one, if we don't have enough matches we are unable to get a unique solution. So in that case we can not find the OPR values. It is also possible that we find ourselves with too many matches. In that case we use the least squares approximation.

# %% [markdown]
# The OPR system gives us another way to look at the points each team may contribute. A bad team might have a lot of matches where their alliance scores a lot of points, but that is only because they are partnered up with good alliance members. The OPR system attempts to downplay their contribution if everyone on their team are known to score a lot of points on average. Also by the nature of linear systems of equations, it is possible for a team's OPR to be negative which represents the fact that a team might actually be a detriment to their alliance.

# %% [markdown]
# For our model we will need a way to compare the alliance's OPRs. We can not take the difference since, as stated previously, each season comes with a different game which implies different average point values. Since the OPR of an alliance is the predicted number of points they will receive, the average OPR will change per season. To create a variable that compares the two OPRs we will add a 100,000 to each OPR and then divide the red OPR by the blue OPR. We are doing this for the same reason we took the ratio of average points. We offset the OPR by 100,000 because OPRs can be negative so a straight division between the two OPRs might not be useful. No season has ever reached a max points cap of 100,000 so we can ensure ourselves that we are not going to be dividing any negative numbers.

# %% [markdown]
# To learn more about the Offensive Power Rating system look here: https://blog.thebluealliance.com/2017/10/05/the-math-behind-opr-an-introduction/

# %% [markdown]
# #### Competition OPR

# %%
#Calculate Competition OPR
match_df['red_opr'] = 0
match_df['blue_opr'] = 0
match_df['opr_ratio'] = 1
opr_offset = 100000

# Used to make opr calculation easier
class MatchOPRCounter:
    
    def __init__(self, event_key):
        self.event_key = event_key
        #2D matrix of all the matches
        #The A in Ax=B
        self._match_matrix = []
        #The B in Ax=B
        self._match_score_vector = []
        #Matches team key to position on index
        self._team_positions = {}
        #Current OPRs for teams
        self._team_oprs = {}
        
    def get_opr(self, team_key):
        return self._team_oprs.get(team_key, None)

    def get_alliance_opr(self, alliance):
        opr = 0
        for alliance_member in alliance:
          if alliance_member in self._team_oprs:
            opr += self.get_opr(alliance_member)
          else:
            return None

        return opr
    
    def record_half_match(self, alliance, score):
        for alliance_member in alliance:
            if alliance_member not in self._team_positions:
                self._add_team(alliance_member)
                
        opr_match_info = [0] * len(self._team_positions)
        for alliance_member in alliance:
            opr_match_info[self._team_positions[alliance_member]] = 1
        
        self._match_matrix.append(opr_match_info)
        self._match_score_vector.append(score)
    
    def _add_team(self, team_key):
        self._team_positions[team_key] = len(self._team_positions)
        
        for opr_match_info in self._match_matrix:
            opr_match_info.append(0)
    
    def update_oprs(self):
        match_matrix = torch.tensor(self._match_matrix, device="cuda", dtype=torch.float64)
        score_vector = torch.tensor(self._match_score_vector, device="cuda", dtype=torch.float64)
        
        #For the least squares solution
        normal_matrix = match_matrix.t().mm(match_matrix)
        normal_score = match_matrix.t().mv(score_vector)

        #Checks if it is invertible
        if -0.001 < normal_matrix.det() < 0.001:
          return

        try:
          raw_oprs, LU = normal_score.view(normal_score.shape[0], 1).solve(normal_matrix)
        except:
          return

        for team_key, index in self._team_positions.items():
          self._team_oprs[team_key] = int(raw_oprs[index])

#Simulates matches to calculate opr
match_oprs = {}
for index, row in match_df.iterrows():
    
    print('Calculating OPR for match ' + str(index + 1) + "/" + str(len_match))
    
    event_key = row['event_key']
    
    if event_key not in match_oprs:
        match_oprs[event_key] = MatchOPRCounter(event_key)
        
    opr_counter = match_oprs[event_key]
    
    #Get the red and blue alliance
    red_alliance = [row['red_0'], row['red_1'], row['red_2']]
    blue_alliance = [row['blue_0'], row['blue_1'], row['blue_2']]

    red_opr = opr_counter.get_alliance_opr(red_alliance)
    blue_opr = opr_counter.get_alliance_opr(blue_alliance)

    row['blue_opr'] = blue_opr
    row['red_opr'] = red_opr

    if blue_opr is not None and red_opr is not None:
      row['opr_ratio'] = (red_opr + opr_offset) / (blue_opr + opr_offset)
    
    opr_counter.record_half_match(red_alliance, row['red_score'])
    opr_counter.record_half_match(blue_alliance, row['blue_score'])
    
    opr_counter.update_oprs()

    match_df.loc[index] = row
# Out:
# Streaming output truncated to the last 5000 lines.
# Calculating OPR for match 67793/72791
# Calculating OPR for match 67794/72791
# Calculating OPR for match 67795/72791
# Calculating OPR for match 67796/72791
# Calculating OPR for match 67797/72791
# Calculating OPR for match 67798/72791
# Calculating OPR for match 67799/72791
# Calculating OPR for match 67800/72791
# Calculating OPR for match 67801/72791
# Calculating OPR for match 67802/72791
# Calculating OPR for match 67803/72791
# Calculating OPR for match 67804/72791
# Calculating OPR for match 67805/72791
# Calculating OPR for match 67806/72791
# Calculating OPR for match 67807/72791
# Calculating OPR for match 67808/72791
# Calculating OPR for match 67809/72791
# Calculating OPR for match 67810/72791
# Calculating OPR for match 67811/72791
# Calculating OPR for match 67812/72791
# Calculating OPR for match 67813/72791
# Calculating OPR for match 67814/72791
# Calculating OPR for match 67815/72791
# Calculating OPR for match 67816/72791
# Calculating OPR for match 67817/72791
# Calculating OPR for match 67818/72791
# Calculating OPR for match 67819/72791
# Calculating OPR for match 67820/72791
# Calculating OPR for match 67821/72791
# Calculating OPR for match 67822/72791
# Calculating OPR for match 67823/72791
# Calculating OPR for match 67824/72791
# Calculating OPR for match 67825/72791
# Calculating OPR for match 67826/72791
# Calculating OPR for match 67827/72791
# Calculating OPR for match 67828/72791
# Calculating OPR for match 67829/72791
# Calculating OPR for match 67830/72791
# Calculating OPR for match 67831/72791
# Calculating OPR for match 67832/72791
# Calculating OPR for match 67833/72791
# Calculating OPR for match 67834/72791
# Calculating OPR for match 67835/72791
# Calculating OPR for match 67836/72791
# Calculating OPR for match 67837/72791
# Calculating OPR for match 67838/72791
# Calculating OPR for match 67839/72791
# Calculating OPR for match 67840/72791
# Calculating OPR for match 67841/72791
# Calculating OPR for match 67842/72791
# Calculating OPR for match 67843/72791
# Calculating OPR for match 67844/72791
# Calculating OPR for match 67845/72791
# Calculating OPR for match 67846/72791
# Calculating OPR for match 67847/72791
# Calculating OPR for match 67848/72791
# Calculating OPR for match 67849/72791
# Calculating OPR for match 67850/72791
# Calculating OPR for match 67851/72791
# Calculating OPR for match 67852/72791
# Calculating OPR for match 67853/72791
# Calculating OPR for match 67854/72791
# Calculating OPR for match 67855/72791
# Calculating OPR for match 67856/72791
# Calculating OPR for match 67857/72791
# Calculating OPR for match 67858/72791
# Calculating OPR for match 67859/72791
# Calculating OPR for match 67860/72791
# Calculating OPR for match 67861/72791
# Calculating OPR for match 67862/72791
# Calculating OPR for match 67863/72791
# Calculating OPR for match 67864/72791
# Calculating OPR for match 67865/72791
# Calculating OPR for match 67866/72791
# Calculating OPR for match 67867/72791
# Calculating OPR for match 67868/72791
# Calculating OPR for match 67869/72791
# Calculating OPR for match 67870/72791
# Calculating OPR for match 67871/72791
# Calculating OPR for match 67872/72791
# Calculating OPR for match 67873/72791
# Calculating OPR for match 67874/72791
# Calculating OPR for match 67875/72791
# Calculating OPR for match 67876/72791
# Calculating OPR for match 67877/72791
# Calculating OPR for match 67878/72791
# Calculating OPR for match 67879/72791
# Calculating OPR for match 67880/72791
# Calculating OPR for match 67881/72791
# Calculating OPR for match 67882/72791
# Calculating OPR for match 67883/72791
# Calculating OPR for match 67884/72791
# Calculating OPR for match 67885/72791
# Calculating OPR for match 67886/72791
# Calculating OPR for match 67887/72791
# Calculating OPR for match 67888/72791
# Calculating OPR for match 67889/72791
# Calculating OPR for match 67890/72791
# Calculating OPR for match 67891/72791
# Calculating OPR for match 67892/72791
# Calculating OPR for match 67893/72791
# Calculating OPR for match 67894/72791
# Calculating OPR for match 67895/72791
# Calculating OPR for match 67896/72791
# Calculating OPR for match 67897/72791
# Calculating OPR for match 67898/72791
# Calculating OPR for match 67899/72791
# Calculating OPR for match 67900/72791
# Calculating OPR for match 67901/72791
# Calculating OPR for match 67902/72791
# Calculating OPR for match 67903/72791
# Calculating OPR for match 67904/72791
# Calculating OPR for match 67905/72791
# Calculating OPR for match 67906/72791
# Calculating OPR for match 67907/72791
# Calculating OPR for match 67908/72791
# Calculating OPR for match 67909/72791
# Calculating OPR for match 67910/72791
# Calculating OPR for match 67911/72791
# Calculating OPR for match 67912/72791
# Calculating OPR for match 67913/72791
# Calculating OPR for match 67914/72791
# Calculating OPR for match 67915/72791
# Calculating OPR for match 67916/72791
# Calculating OPR for match 67917/72791
# Calculating OPR for match 67918/72791
# Calculating OPR for match 67919/72791
# Calculating OPR for match 67920/72791
# Calculating OPR for match 67921/72791
# Calculating OPR for match 67922/72791
# Calculating OPR for match 67923/72791
# Calculating OPR for match 67924/72791
# Calculating OPR for match 67925/72791
# Calculating OPR for match 67926/72791
# Calculating OPR for match 67927/72791
# Calculating OPR for match 67928/72791
# Calculating OPR for match 67929/72791
# Calculating OPR for match 67930/72791
# Calculating OPR for match 67931/72791
# Calculating OPR for match 67932/72791
# Calculating OPR for match 67933/72791
# Calculating OPR for match 67934/72791
# Calculating OPR for match 67935/72791
# Calculating OPR for match 67936/72791
# Calculating OPR for match 67937/72791
# Calculating OPR for match 67938/72791
# Calculating OPR for match 67939/72791
# Calculating OPR for match 67940/72791
# Calculating OPR for match 67941/72791
# Calculating OPR for match 67942/72791
# Calculating OPR for match 67943/72791
# Calculating OPR for match 67944/72791
# Calculating OPR for match 67945/72791
# Calculating OPR for match 67946/72791
# Calculating OPR for match 67947/72791
# Calculating OPR for match 67948/72791
# Calculating OPR for match 67949/72791
# Calculating OPR for match 67950/72791
# Calculating OPR for match 67951/72791
# Calculating OPR for match 67952/72791
# Calculating OPR for match 67953/72791
# Calculating OPR for match 67954/72791
# Calculating OPR for match 67955/72791
# Calculating OPR for match 67956/72791
# Calculating OPR for match 67957/72791
# Calculating OPR for match 67958/72791
# Calculating OPR for match 67959/72791
# Calculating OPR for match 67960/72791
# Calculating OPR for match 67961/72791
# Calculating OPR for match 67962/72791
# Calculating OPR for match 67963/72791
# Calculating OPR for match 67964/72791
# Calculating OPR for match 67965/72791
# Calculating OPR for match 67966/72791
# Calculating OPR for match 67967/72791
# Calculating OPR for match 67968/72791
# Calculating OPR for match 67969/72791
# Calculating OPR for match 67970/72791
# Calculating OPR for match 67971/72791
# Calculating OPR for match 67972/72791
# Calculating OPR for match 67973/72791
# Calculating OPR for match 67974/72791
# Calculating OPR for match 67975/72791
# Calculating OPR for match 67976/72791
# Calculating OPR for match 67977/72791
# Calculating OPR for match 67978/72791
# Calculating OPR for match 67979/72791
# Calculating OPR for match 67980/72791
# Calculating OPR for match 67981/72791
# Calculating OPR for match 67982/72791
# Calculating OPR for match 67983/72791
# Calculating OPR for match 67984/72791
# Calculating OPR for match 67985/72791
# Calculating OPR for match 67986/72791
# Calculating OPR for match 67987/72791
# Calculating OPR for match 67988/72791
# Calculating OPR for match 67989/72791
# Calculating OPR for match 67990/72791
# Calculating OPR for match 67991/72791
# Calculating OPR for match 67992/72791
# Calculating OPR for match 67993/72791
# Calculating OPR for match 67994/72791
# Calculating OPR for match 67995/72791
# Calculating OPR for match 67996/72791
# Calculating OPR for match 67997/72791
# Calculating OPR for match 67998/72791
# Calculating OPR for match 67999/72791
# Calculating OPR for match 68000/72791
# Calculating OPR for match 68001/72791
# Calculating OPR for match 68002/72791
# Calculating OPR for match 68003/72791
# Calculating OPR for match 68004/72791
# Calculating OPR for match 68005/72791
# Calculating OPR for match 68006/72791
# Calculating OPR for match 68007/72791
# Calculating OPR for match 68008/72791
# Calculating OPR for match 68009/72791
# Calculating OPR for match 68010/72791
# Calculating OPR for match 68011/72791
# Calculating OPR for match 68012/72791
# Calculating OPR for match 68013/72791
# Calculating OPR for match 68014/72791
# Calculating OPR for match 68015/72791
# Calculating OPR for match 68016/72791
# Calculating OPR for match 68017/72791
# Calculating OPR for match 68018/72791
# Calculating OPR for match 68019/72791
# Calculating OPR for match 68020/72791
# Calculating OPR for match 68021/72791
# Calculating OPR for match 68022/72791
# Calculating OPR for match 68023/72791
# Calculating OPR for match 68024/72791
# Calculating OPR for match 68025/72791
# Calculating OPR for match 68026/72791
# Calculating OPR for match 68027/72791
# Calculating OPR for match 68028/72791
# Calculating OPR for match 68029/72791
# Calculating OPR for match 68030/72791
# Calculating OPR for match 68031/72791
# Calculating OPR for match 68032/72791
# Calculating OPR for match 68033/72791
# Calculating OPR for match 68034/72791
# Calculating OPR for match 68035/72791
# Calculating OPR for match 68036/72791
# Calculating OPR for match 68037/72791
# Calculating OPR for match 68038/72791
# Calculating OPR for match 68039/72791
# Calculating OPR for match 68040/72791
# Calculating OPR for match 68041/72791
# Calculating OPR for match 68042/72791
# Calculating OPR for match 68043/72791
# Calculating OPR for match 68044/72791
# Calculating OPR for match 68045/72791
# Calculating OPR for match 68046/72791
# Calculating OPR for match 68047/72791
# Calculating OPR for match 68048/72791
# Calculating OPR for match 68049/72791
# Calculating OPR for match 68050/72791
# Calculating OPR for match 68051/72791
# Calculating OPR for match 68052/72791
# Calculating OPR for match 68053/72791
# Calculating OPR for match 68054/72791
# Calculating OPR for match 68055/72791
# Calculating OPR for match 68056/72791
# Calculating OPR for match 68057/72791
# Calculating OPR for match 68058/72791
# Calculating OPR for match 68059/72791
# Calculating OPR for match 68060/72791
# Calculating OPR for match 68061/72791
# Calculating OPR for match 68062/72791
# Calculating OPR for match 68063/72791
# Calculating OPR for match 68064/72791
# Calculating OPR for match 68065/72791
# Calculating OPR for match 68066/72791
# Calculating OPR for match 68067/72791
# Calculating OPR for match 68068/72791
# Calculating OPR for match 68069/72791
# Calculating OPR for match 68070/72791
# Calculating OPR for match 68071/72791
# Calculating OPR for match 68072/72791
# Calculating OPR for match 68073/72791
# Calculating OPR for match 68074/72791
# Calculating OPR for match 68075/72791
# Calculating OPR for match 68076/72791
# Calculating OPR for match 68077/72791
# Calculating OPR for match 68078/72791
# Calculating OPR for match 68079/72791
# Calculating OPR for match 68080/72791
# Calculating OPR for match 68081/72791
# Calculating OPR for match 68082/72791
# Calculating OPR for match 68083/72791
# Calculating OPR for match 68084/72791
# Calculating OPR for match 68085/72791
# Calculating OPR for match 68086/72791
# Calculating OPR for match 68087/72791
# Calculating OPR for match 68088/72791
# Calculating OPR for match 68089/72791
# Calculating OPR for match 68090/72791
# Calculating OPR for match 68091/72791
# Calculating OPR for match 68092/72791
# Calculating OPR for match 68093/72791
# Calculating OPR for match 68094/72791
# Calculating OPR for match 68095/72791
# Calculating OPR for match 68096/72791
# Calculating OPR for match 68097/72791
# Calculating OPR for match 68098/72791
# Calculating OPR for match 68099/72791
# Calculating OPR for match 68100/72791
# Calculating OPR for match 68101/72791
# Calculating OPR for match 68102/72791
# Calculating OPR for match 68103/72791
# Calculating OPR for match 68104/72791
# Calculating OPR for match 68105/72791
# Calculating OPR for match 68106/72791
# Calculating OPR for match 68107/72791
# Calculating OPR for match 68108/72791
# Calculating OPR for match 68109/72791
# Calculating OPR for match 68110/72791
# Calculating OPR for match 68111/72791
# Calculating OPR for match 68112/72791
# Calculating OPR for match 68113/72791
# Calculating OPR for match 68114/72791
# Calculating OPR for match 68115/72791
# Calculating OPR for match 68116/72791
# Calculating OPR for match 68117/72791
# Calculating OPR for match 68118/72791
# Calculating OPR for match 68119/72791
# Calculating OPR for match 68120/72791
# Calculating OPR for match 68121/72791
# Calculating OPR for match 68122/72791
# Calculating OPR for match 68123/72791
# Calculating OPR for match 68124/72791
# Calculating OPR for match 68125/72791
# Calculating OPR for match 68126/72791
# Calculating OPR for match 68127/72791
# Calculating OPR for match 68128/72791
# Calculating OPR for match 68129/72791
# Calculating OPR for match 68130/72791
# Calculating OPR for match 68131/72791
# Calculating OPR for match 68132/72791
# Calculating OPR for match 68133/72791
# Calculating OPR for match 68134/72791
# Calculating OPR for match 68135/72791
# Calculating OPR for match 68136/72791
# Calculating OPR for match 68137/72791
# Calculating OPR for match 68138/72791
# Calculating OPR for match 68139/72791
# Calculating OPR for match 68140/72791
# Calculating OPR for match 68141/72791
# Calculating OPR for match 68142/72791
# Calculating OPR for match 68143/72791
# Calculating OPR for match 68144/72791
# Calculating OPR for match 68145/72791
# Calculating OPR for match 68146/72791
# Calculating OPR for match 68147/72791
# Calculating OPR for match 68148/72791
# Calculating OPR for match 68149/72791
# Calculating OPR for match 68150/72791
# Calculating OPR for match 68151/72791
# Calculating OPR for match 68152/72791
# Calculating OPR for match 68153/72791
# Calculating OPR for match 68154/72791
# Calculating OPR for match 68155/72791
# Calculating OPR for match 68156/72791
# Calculating OPR for match 68157/72791
# Calculating OPR for match 68158/72791
# Calculating OPR for match 68159/72791
# Calculating OPR for match 68160/72791
# Calculating OPR for match 68161/72791
# Calculating OPR for match 68162/72791
# Calculating OPR for match 68163/72791
# Calculating OPR for match 68164/72791
# Calculating OPR for match 68165/72791
# Calculating OPR for match 68166/72791
# Calculating OPR for match 68167/72791
# Calculating OPR for match 68168/72791
# Calculating OPR for match 68169/72791
# Calculating OPR for match 68170/72791
# Calculating OPR for match 68171/72791
# Calculating OPR for match 68172/72791
# Calculating OPR for match 68173/72791
# Calculating OPR for match 68174/72791
# Calculating OPR for match 68175/72791
# Calculating OPR for match 68176/72791
# Calculating OPR for match 68177/72791
# Calculating OPR for match 68178/72791
# Calculating OPR for match 68179/72791
# Calculating OPR for match 68180/72791
# Calculating OPR for match 68181/72791
# Calculating OPR for match 68182/72791
# Calculating OPR for match 68183/72791
# Calculating OPR for match 68184/72791
# Calculating OPR for match 68185/72791
# Calculating OPR for match 68186/72791
# Calculating OPR for match 68187/72791
# Calculating OPR for match 68188/72791
# Calculating OPR for match 68189/72791
# Calculating OPR for match 68190/72791
# Calculating OPR for match 68191/72791
# Calculating OPR for match 68192/72791
# Calculating OPR for match 68193/72791
# Calculating OPR for match 68194/72791
# Calculating OPR for match 68195/72791
# Calculating OPR for match 68196/72791
# Calculating OPR for match 68197/72791
# Calculating OPR for match 68198/72791
# Calculating OPR for match 68199/72791
# Calculating OPR for match 68200/72791
# Calculating OPR for match 68201/72791
# Calculating OPR for match 68202/72791
# Calculating OPR for match 68203/72791
# Calculating OPR for match 68204/72791
# Calculating OPR for match 68205/72791
# Calculating OPR for match 68206/72791
# Calculating OPR for match 68207/72791
# Calculating OPR for match 68208/72791
# Calculating OPR for match 68209/72791
# Calculating OPR for match 68210/72791
# Calculating OPR for match 68211/72791
# Calculating OPR for match 68212/72791
# Calculating OPR for match 68213/72791
# Calculating OPR for match 68214/72791
# Calculating OPR for match 68215/72791
# Calculating OPR for match 68216/72791
# Calculating OPR for match 68217/72791
# Calculating OPR for match 68218/72791
# Calculating OPR for match 68219/72791
# Calculating OPR for match 68220/72791
# Calculating OPR for match 68221/72791
# Calculating OPR for match 68222/72791
# Calculating OPR for match 68223/72791
# Calculating OPR for match 68224/72791
# Calculating OPR for match 68225/72791
# Calculating OPR for match 68226/72791
# Calculating OPR for match 68227/72791
# Calculating OPR for match 68228/72791
# Calculating OPR for match 68229/72791
# Calculating OPR for match 68230/72791
# Calculating OPR for match 68231/72791
# Calculating OPR for match 68232/72791
# Calculating OPR for match 68233/72791
# Calculating OPR for match 68234/72791
# Calculating OPR for match 68235/72791
# Calculating OPR for match 68236/72791
# Calculating OPR for match 68237/72791
# Calculating OPR for match 68238/72791
# Calculating OPR for match 68239/72791
# Calculating OPR for match 68240/72791
# Calculating OPR for match 68241/72791
# Calculating OPR for match 68242/72791
# Calculating OPR for match 68243/72791
# Calculating OPR for match 68244/72791
# Calculating OPR for match 68245/72791
# Calculating OPR for match 68246/72791
# Calculating OPR for match 68247/72791
# Calculating OPR for match 68248/72791
# Calculating OPR for match 68249/72791
# Calculating OPR for match 68250/72791
# Calculating OPR for match 68251/72791
# Calculating OPR for match 68252/72791
# Calculating OPR for match 68253/72791
# Calculating OPR for match 68254/72791
# Calculating OPR for match 68255/72791
# Calculating OPR for match 68256/72791
# Calculating OPR for match 68257/72791
# Calculating OPR for match 68258/72791
# Calculating OPR for match 68259/72791
# Calculating OPR for match 68260/72791
# Calculating OPR for match 68261/72791
# Calculating OPR for match 68262/72791
# Calculating OPR for match 68263/72791
# Calculating OPR for match 68264/72791
# Calculating OPR for match 68265/72791
# Calculating OPR for match 68266/72791
# Calculating OPR for match 68267/72791
# Calculating OPR for match 68268/72791
# Calculating OPR for match 68269/72791
# Calculating OPR for match 68270/72791
# Calculating OPR for match 68271/72791
# Calculating OPR for match 68272/72791
# Calculating OPR for match 68273/72791
# Calculating OPR for match 68274/72791
# Calculating OPR for match 68275/72791
# Calculating OPR for match 68276/72791
# Calculating OPR for match 68277/72791
# Calculating OPR for match 68278/72791
# Calculating OPR for match 68279/72791
# Calculating OPR for match 68280/72791
# Calculating OPR for match 68281/72791
# Calculating OPR for match 68282/72791
# Calculating OPR for match 68283/72791
# Calculating OPR for match 68284/72791
# Calculating OPR for match 68285/72791
# Calculating OPR for match 68286/72791
# Calculating OPR for match 68287/72791
# Calculating OPR for match 68288/72791
# Calculating OPR for match 68289/72791
# Calculating OPR for match 68290/72791
# Calculating OPR for match 68291/72791
# Calculating OPR for match 68292/72791
# Calculating OPR for match 68293/72791
# Calculating OPR for match 68294/72791
# Calculating OPR for match 68295/72791
# Calculating OPR for match 68296/72791
# Calculating OPR for match 68297/72791
# Calculating OPR for match 68298/72791
# Calculating OPR for match 68299/72791
# Calculating OPR for match 68300/72791
# Calculating OPR for match 68301/72791
# Calculating OPR for match 68302/72791
# Calculating OPR for match 68303/72791
# Calculating OPR for match 68304/72791
# Calculating OPR for match 68305/72791
# Calculating OPR for match 68306/72791
# Calculating OPR for match 68307/72791
# Calculating OPR for match 68308/72791
# Calculating OPR for match 68309/72791
# Calculating OPR for match 68310/72791
# Calculating OPR for match 68311/72791
# Calculating OPR for match 68312/72791
# Calculating OPR for match 68313/72791
# Calculating OPR for match 68314/72791
# Calculating OPR for match 68315/72791
# Calculating OPR for match 68316/72791
# Calculating OPR for match 68317/72791
# Calculating OPR for match 68318/72791
# Calculating OPR for match 68319/72791
# Calculating OPR for match 68320/72791
# Calculating OPR for match 68321/72791
# Calculating OPR for match 68322/72791
# Calculating OPR for match 68323/72791
# Calculating OPR for match 68324/72791
# Calculating OPR for match 68325/72791
# Calculating OPR for match 68326/72791
# Calculating OPR for match 68327/72791
# Calculating OPR for match 68328/72791
# Calculating OPR for match 68329/72791
# Calculating OPR for match 68330/72791
# Calculating OPR for match 68331/72791
# Calculating OPR for match 68332/72791
# Calculating OPR for match 68333/72791
# Calculating OPR for match 68334/72791
# Calculating OPR for match 68335/72791
# Calculating OPR for match 68336/72791
# Calculating OPR for match 68337/72791
# Calculating OPR for match 68338/72791
# Calculating OPR for match 68339/72791
# Calculating OPR for match 68340/72791
# Calculating OPR for match 68341/72791
# Calculating OPR for match 68342/72791
# Calculating OPR for match 68343/72791
# Calculating OPR for match 68344/72791
# Calculating OPR for match 68345/72791
# Calculating OPR for match 68346/72791
# Calculating OPR for match 68347/72791
# Calculating OPR for match 68348/72791
# Calculating OPR for match 68349/72791
# Calculating OPR for match 68350/72791
# Calculating OPR for match 68351/72791
# Calculating OPR for match 68352/72791
# Calculating OPR for match 68353/72791
# Calculating OPR for match 68354/72791
# Calculating OPR for match 68355/72791
# Calculating OPR for match 68356/72791
# Calculating OPR for match 68357/72791
# Calculating OPR for match 68358/72791
# Calculating OPR for match 68359/72791
# Calculating OPR for match 68360/72791
# Calculating OPR for match 68361/72791
# Calculating OPR for match 68362/72791
# Calculating OPR for match 68363/72791
# Calculating OPR for match 68364/72791
# Calculating OPR for match 68365/72791
# Calculating OPR for match 68366/72791
# Calculating OPR for match 68367/72791
# Calculating OPR for match 68368/72791
# Calculating OPR for match 68369/72791
# Calculating OPR for match 68370/72791
# Calculating OPR for match 68371/72791
# Calculating OPR for match 68372/72791
# Calculating OPR for match 68373/72791
# Calculating OPR for match 68374/72791
# Calculating OPR for match 68375/72791
# Calculating OPR for match 68376/72791
# Calculating OPR for match 68377/72791
# Calculating OPR for match 68378/72791
# Calculating OPR for match 68379/72791
# Calculating OPR for match 68380/72791
# Calculating OPR for match 68381/72791
# Calculating OPR for match 68382/72791
# Calculating OPR for match 68383/72791
# Calculating OPR for match 68384/72791
# Calculating OPR for match 68385/72791
# Calculating OPR for match 68386/72791
# Calculating OPR for match 68387/72791
# Calculating OPR for match 68388/72791
# Calculating OPR for match 68389/72791
# Calculating OPR for match 68390/72791
# Calculating OPR for match 68391/72791
# Calculating OPR for match 68392/72791
# Calculating OPR for match 68393/72791
# Calculating OPR for match 68394/72791
# Calculating OPR for match 68395/72791
# Calculating OPR for match 68396/72791
# Calculating OPR for match 68397/72791
# Calculating OPR for match 68398/72791
# Calculating OPR for match 68399/72791
# Calculating OPR for match 68400/72791
# Calculating OPR for match 68401/72791
# Calculating OPR for match 68402/72791
# Calculating OPR for match 68403/72791
# Calculating OPR for match 68404/72791
# Calculating OPR for match 68405/72791
# Calculating OPR for match 68406/72791
# Calculating OPR for match 68407/72791
# Calculating OPR for match 68408/72791
# Calculating OPR for match 68409/72791
# Calculating OPR for match 68410/72791
# Calculating OPR for match 68411/72791
# Calculating OPR for match 68412/72791
# Calculating OPR for match 68413/72791
# Calculating OPR for match 68414/72791
# Calculating OPR for match 68415/72791
# Calculating OPR for match 68416/72791
# Calculating OPR for match 68417/72791
# Calculating OPR for match 68418/72791
# Calculating OPR for match 68419/72791
# Calculating OPR for match 68420/72791
# Calculating OPR for match 68421/72791
# Calculating OPR for match 68422/72791
# Calculating OPR for match 68423/72791
# Calculating OPR for match 68424/72791
# Calculating OPR for match 68425/72791
# Calculating OPR for match 68426/72791
# Calculating OPR for match 68427/72791
# Calculating OPR for match 68428/72791
# Calculating OPR for match 68429/72791
# Calculating OPR for match 68430/72791
# Calculating OPR for match 68431/72791
# Calculating OPR for match 68432/72791
# Calculating OPR for match 68433/72791
# Calculating OPR for match 68434/72791
# Calculating OPR for match 68435/72791
# Calculating OPR for match 68436/72791
# Calculating OPR for match 68437/72791
# Calculating OPR for match 68438/72791
# Calculating OPR for match 68439/72791
# Calculating OPR for match 68440/72791
# Calculating OPR for match 68441/72791
# Calculating OPR for match 68442/72791
# Calculating OPR for match 68443/72791
# Calculating OPR for match 68444/72791
# Calculating OPR for match 68445/72791
# Calculating OPR for match 68446/72791
# Calculating OPR for match 68447/72791
# Calculating OPR for match 68448/72791
# Calculating OPR for match 68449/72791
# Calculating OPR for match 68450/72791
# Calculating OPR for match 68451/72791
# Calculating OPR for match 68452/72791
# Calculating OPR for match 68453/72791
# Calculating OPR for match 68454/72791
# Calculating OPR for match 68455/72791
# Calculating OPR for match 68456/72791
# Calculating OPR for match 68457/72791
# Calculating OPR for match 68458/72791
# Calculating OPR for match 68459/72791
# Calculating OPR for match 68460/72791
# Calculating OPR for match 68461/72791
# Calculating OPR for match 68462/72791
# Calculating OPR for match 68463/72791
# Calculating OPR for match 68464/72791
# Calculating OPR for match 68465/72791
# Calculating OPR for match 68466/72791
# Calculating OPR for match 68467/72791
# Calculating OPR for match 68468/72791
# Calculating OPR for match 68469/72791
# Calculating OPR for match 68470/72791
# Calculating OPR for match 68471/72791
# Calculating OPR for match 68472/72791
# Calculating OPR for match 68473/72791
# Calculating OPR for match 68474/72791
# Calculating OPR for match 68475/72791
# Calculating OPR for match 68476/72791
# Calculating OPR for match 68477/72791
# Calculating OPR for match 68478/72791
# Calculating OPR for match 68479/72791
# Calculating OPR for match 68480/72791
# Calculating OPR for match 68481/72791
# Calculating OPR for match 68482/72791
# Calculating OPR for match 68483/72791
# Calculating OPR for match 68484/72791
# Calculating OPR for match 68485/72791
# Calculating OPR for match 68486/72791
# Calculating OPR for match 68487/72791
# Calculating OPR for match 68488/72791
# Calculating OPR for match 68489/72791
# Calculating OPR for match 68490/72791
# Calculating OPR for match 68491/72791
# Calculating OPR for match 68492/72791
# Calculating OPR for match 68493/72791
# Calculating OPR for match 68494/72791
# Calculating OPR for match 68495/72791
# Calculating OPR for match 68496/72791
# Calculating OPR for match 68497/72791
# Calculating OPR for match 68498/72791
# Calculating OPR for match 68499/72791
# Calculating OPR for match 68500/72791
# Calculating OPR for match 68501/72791
# Calculating OPR for match 68502/72791
# Calculating OPR for match 68503/72791
# Calculating OPR for match 68504/72791
# Calculating OPR for match 68505/72791
# Calculating OPR for match 68506/72791
# Calculating OPR for match 68507/72791
# Calculating OPR for match 68508/72791
# Calculating OPR for match 68509/72791
# Calculating OPR for match 68510/72791
# Calculating OPR for match 68511/72791
# Calculating OPR for match 68512/72791
# Calculating OPR for match 68513/72791
# Calculating OPR for match 68514/72791
# Calculating OPR for match 68515/72791
# Calculating OPR for match 68516/72791
# Calculating OPR for match 68517/72791
# Calculating OPR for match 68518/72791
# Calculating OPR for match 68519/72791
# Calculating OPR for match 68520/72791
# Calculating OPR for match 68521/72791
# Calculating OPR for match 68522/72791
# Calculating OPR for match 68523/72791
# Calculating OPR for match 68524/72791
# Calculating OPR for match 68525/72791
# Calculating OPR for match 68526/72791
# Calculating OPR for match 68527/72791
# Calculating OPR for match 68528/72791
# Calculating OPR for match 68529/72791
# Calculating OPR for match 68530/72791
# Calculating OPR for match 68531/72791
# Calculating OPR for match 68532/72791
# Calculating OPR for match 68533/72791
# Calculating OPR for match 68534/72791
# Calculating OPR for match 68535/72791
# Calculating OPR for match 68536/72791
# Calculating OPR for match 68537/72791
# Calculating OPR for match 68538/72791
# Calculating OPR for match 68539/72791
# Calculating OPR for match 68540/72791
# Calculating OPR for match 68541/72791
# Calculating OPR for match 68542/72791
# Calculating OPR for match 68543/72791
# Calculating OPR for match 68544/72791
# Calculating OPR for match 68545/72791
# Calculating OPR for match 68546/72791
# Calculating OPR for match 68547/72791
# Calculating OPR for match 68548/72791
# Calculating OPR for match 68549/72791
# Calculating OPR for match 68550/72791
# Calculating OPR for match 68551/72791
# Calculating OPR for match 68552/72791
# Calculating OPR for match 68553/72791
# Calculating OPR for match 68554/72791
# Calculating OPR for match 68555/72791
# Calculating OPR for match 68556/72791
# Calculating OPR for match 68557/72791
# Calculating OPR for match 68558/72791
# Calculating OPR for match 68559/72791
# Calculating OPR for match 68560/72791
# Calculating OPR for match 68561/72791
# Calculating OPR for match 68562/72791
# Calculating OPR for match 68563/72791
# Calculating OPR for match 68564/72791
# Calculating OPR for match 68565/72791
# Calculating OPR for match 68566/72791
# Calculating OPR for match 68567/72791
# Calculating OPR for match 68568/72791
# Calculating OPR for match 68569/72791
# Calculating OPR for match 68570/72791
# Calculating OPR for match 68571/72791
# Calculating OPR for match 68572/72791
# Calculating OPR for match 68573/72791
# Calculating OPR for match 68574/72791
# Calculating OPR for match 68575/72791
# Calculating OPR for match 68576/72791
# Calculating OPR for match 68577/72791
# Calculating OPR for match 68578/72791
# Calculating OPR for match 68579/72791
# Calculating OPR for match 68580/72791
# Calculating OPR for match 68581/72791
# Calculating OPR for match 68582/72791
# Calculating OPR for match 68583/72791
# Calculating OPR for match 68584/72791
# Calculating OPR for match 68585/72791
# Calculating OPR for match 68586/72791
# Calculating OPR for match 68587/72791
# Calculating OPR for match 68588/72791
# Calculating OPR for match 68589/72791
# Calculating OPR for match 68590/72791
# Calculating OPR for match 68591/72791
# Calculating OPR for match 68592/72791
# Calculating OPR for match 68593/72791
# Calculating OPR for match 68594/72791
# Calculating OPR for match 68595/72791
# Calculating OPR for match 68596/72791
# Calculating OPR for match 68597/72791
# Calculating OPR for match 68598/72791
# Calculating OPR for match 68599/72791
# Calculating OPR for match 68600/72791
# Calculating OPR for match 68601/72791
# Calculating OPR for match 68602/72791
# Calculating OPR for match 68603/72791
# Calculating OPR for match 68604/72791
# Calculating OPR for match 68605/72791
# Calculating OPR for match 68606/72791
# Calculating OPR for match 68607/72791
# Calculating OPR for match 68608/72791
# Calculating OPR for match 68609/72791
# Calculating OPR for match 68610/72791
# Calculating OPR for match 68611/72791
# Calculating OPR for match 68612/72791
# Calculating OPR for match 68613/72791
# Calculating OPR for match 68614/72791
# Calculating OPR for match 68615/72791
# Calculating OPR for match 68616/72791
# Calculating OPR for match 68617/72791
# Calculating OPR for match 68618/72791
# Calculating OPR for match 68619/72791
# Calculating OPR for match 68620/72791
# Calculating OPR for match 68621/72791
# Calculating OPR for match 68622/72791
# Calculating OPR for match 68623/72791
# Calculating OPR for match 68624/72791
# Calculating OPR for match 68625/72791
# Calculating OPR for match 68626/72791
# Calculating OPR for match 68627/72791
# Calculating OPR for match 68628/72791
# Calculating OPR for match 68629/72791
# Calculating OPR for match 68630/72791
# Calculating OPR for match 68631/72791
# Calculating OPR for match 68632/72791
# Calculating OPR for match 68633/72791
# Calculating OPR for match 68634/72791
# Calculating OPR for match 68635/72791
# Calculating OPR for match 68636/72791
# Calculating OPR for match 68637/72791
# Calculating OPR for match 68638/72791
# Calculating OPR for match 68639/72791
# Calculating OPR for match 68640/72791
# Calculating OPR for match 68641/72791
# Calculating OPR for match 68642/72791
# Calculating OPR for match 68643/72791
# Calculating OPR for match 68644/72791
# Calculating OPR for match 68645/72791
# Calculating OPR for match 68646/72791
# Calculating OPR for match 68647/72791
# Calculating OPR for match 68648/72791
# Calculating OPR for match 68649/72791
# Calculating OPR for match 68650/72791
# Calculating OPR for match 68651/72791
# Calculating OPR for match 68652/72791
# Calculating OPR for match 68653/72791
# Calculating OPR for match 68654/72791
# Calculating OPR for match 68655/72791
# Calculating OPR for match 68656/72791
# Calculating OPR for match 68657/72791
# Calculating OPR for match 68658/72791
# Calculating OPR for match 68659/72791
# Calculating OPR for match 68660/72791
# Calculating OPR for match 68661/72791
# Calculating OPR for match 68662/72791
# Calculating OPR for match 68663/72791
# Calculating OPR for match 68664/72791
# Calculating OPR for match 68665/72791
# Calculating OPR for match 68666/72791
# Calculating OPR for match 68667/72791
# Calculating OPR for match 68668/72791
# Calculating OPR for match 68669/72791
# Calculating OPR for match 68670/72791
# Calculating OPR for match 68671/72791
# Calculating OPR for match 68672/72791
# Calculating OPR for match 68673/72791
# Calculating OPR for match 68674/72791
# Calculating OPR for match 68675/72791
# Calculating OPR for match 68676/72791
# Calculating OPR for match 68677/72791
# Calculating OPR for match 68678/72791
# Calculating OPR for match 68679/72791
# Calculating OPR for match 68680/72791
# Calculating OPR for match 68681/72791
# Calculating OPR for match 68682/72791
# Calculating OPR for match 68683/72791
# Calculating OPR for match 68684/72791
# Calculating OPR for match 68685/72791
# Calculating OPR for match 68686/72791
# Calculating OPR for match 68687/72791
# Calculating OPR for match 68688/72791
# Calculating OPR for match 68689/72791
# Calculating OPR for match 68690/72791
# Calculating OPR for match 68691/72791
# Calculating OPR for match 68692/72791
# Calculating OPR for match 68693/72791
# Calculating OPR for match 68694/72791
# Calculating OPR for match 68695/72791
# Calculating OPR for match 68696/72791
# Calculating OPR for match 68697/72791
# Calculating OPR for match 68698/72791
# Calculating OPR for match 68699/72791
# Calculating OPR for match 68700/72791
# Calculating OPR for match 68701/72791
# Calculating OPR for match 68702/72791
# Calculating OPR for match 68703/72791
# Calculating OPR for match 68704/72791
# Calculating OPR for match 68705/72791
# Calculating OPR for match 68706/72791
# Calculating OPR for match 68707/72791
# Calculating OPR for match 68708/72791
# Calculating OPR for match 68709/72791
# Calculating OPR for match 68710/72791
# Calculating OPR for match 68711/72791
# Calculating OPR for match 68712/72791
# Calculating OPR for match 68713/72791
# Calculating OPR for match 68714/72791
# Calculating OPR for match 68715/72791
# Calculating OPR for match 68716/72791
# Calculating OPR for match 68717/72791
# Calculating OPR for match 68718/72791
# Calculating OPR for match 68719/72791
# Calculating OPR for match 68720/72791
# Calculating OPR for match 68721/72791
# Calculating OPR for match 68722/72791
# Calculating OPR for match 68723/72791
# Calculating OPR for match 68724/72791
# Calculating OPR for match 68725/72791
# Calculating OPR for match 68726/72791
# Calculating OPR for match 68727/72791
# Calculating OPR for match 68728/72791
# Calculating OPR for match 68729/72791
# Calculating OPR for match 68730/72791
# Calculating OPR for match 68731/72791
# Calculating OPR for match 68732/72791
# Calculating OPR for match 68733/72791
# Calculating OPR for match 68734/72791
# Calculating OPR for match 68735/72791
# Calculating OPR for match 68736/72791
# Calculating OPR for match 68737/72791
# Calculating OPR for match 68738/72791
# Calculating OPR for match 68739/72791
# Calculating OPR for match 68740/72791
# Calculating OPR for match 68741/72791
# Calculating OPR for match 68742/72791
# Calculating OPR for match 68743/72791
# Calculating OPR for match 68744/72791
# Calculating OPR for match 68745/72791
# Calculating OPR for match 68746/72791
# Calculating OPR for match 68747/72791
# Calculating OPR for match 68748/72791
# Calculating OPR for match 68749/72791
# Calculating OPR for match 68750/72791
# Calculating OPR for match 68751/72791
# Calculating OPR for match 68752/72791
# Calculating OPR for match 68753/72791
# Calculating OPR for match 68754/72791
# Calculating OPR for match 68755/72791
# Calculating OPR for match 68756/72791
# Calculating OPR for match 68757/72791
# Calculating OPR for match 68758/72791
# Calculating OPR for match 68759/72791
# Calculating OPR for match 68760/72791
# Calculating OPR for match 68761/72791
# Calculating OPR for match 68762/72791
# Calculating OPR for match 68763/72791
# Calculating OPR for match 68764/72791
# Calculating OPR for match 68765/72791
# Calculating OPR for match 68766/72791
# Calculating OPR for match 68767/72791
# Calculating OPR for match 68768/72791
# Calculating OPR for match 68769/72791
# Calculating OPR for match 68770/72791
# Calculating OPR for match 68771/72791
# Calculating OPR for match 68772/72791
# Calculating OPR for match 68773/72791
# Calculating OPR for match 68774/72791
# Calculating OPR for match 68775/72791
# Calculating OPR for match 68776/72791
# Calculating OPR for match 68777/72791
# Calculating OPR for match 68778/72791
# Calculating OPR for match 68779/72791
# Calculating OPR for match 68780/72791
# Calculating OPR for match 68781/72791
# Calculating OPR for match 68782/72791
# Calculating OPR for match 68783/72791
# Calculating OPR for match 68784/72791
# Calculating OPR for match 68785/72791
# Calculating OPR for match 68786/72791
# Calculating OPR for match 68787/72791
# Calculating OPR for match 68788/72791
# Calculating OPR for match 68789/72791
# Calculating OPR for match 68790/72791
# Calculating OPR for match 68791/72791
# Calculating OPR for match 68792/72791
# Calculating OPR for match 68793/72791
# Calculating OPR for match 68794/72791
# Calculating OPR for match 68795/72791
# Calculating OPR for match 68796/72791
# Calculating OPR for match 68797/72791
# Calculating OPR for match 68798/72791
# Calculating OPR for match 68799/72791
# Calculating OPR for match 68800/72791
# Calculating OPR for match 68801/72791
# Calculating OPR for match 68802/72791
# Calculating OPR for match 68803/72791
# Calculating OPR for match 68804/72791
# Calculating OPR for match 68805/72791
# Calculating OPR for match 68806/72791
# Calculating OPR for match 68807/72791
# Calculating OPR for match 68808/72791
# Calculating OPR for match 68809/72791
# Calculating OPR for match 68810/72791
# Calculating OPR for match 68811/72791
# Calculating OPR for match 68812/72791
# Calculating OPR for match 68813/72791
# Calculating OPR for match 68814/72791
# Calculating OPR for match 68815/72791
# Calculating OPR for match 68816/72791
# Calculating OPR for match 68817/72791
# Calculating OPR for match 68818/72791
# Calculating OPR for match 68819/72791
# Calculating OPR for match 68820/72791
# Calculating OPR for match 68821/72791
# Calculating OPR for match 68822/72791
# Calculating OPR for match 68823/72791
# Calculating OPR for match 68824/72791
# Calculating OPR for match 68825/72791
# Calculating OPR for match 68826/72791
# Calculating OPR for match 68827/72791
# Calculating OPR for match 68828/72791
# Calculating OPR for match 68829/72791
# Calculating OPR for match 68830/72791
# Calculating OPR for match 68831/72791
# Calculating OPR for match 68832/72791
# Calculating OPR for match 68833/72791
# Calculating OPR for match 68834/72791
# Calculating OPR for match 68835/72791
# Calculating OPR for match 68836/72791
# Calculating OPR for match 68837/72791
# Calculating OPR for match 68838/72791
# Calculating OPR for match 68839/72791
# Calculating OPR for match 68840/72791
# Calculating OPR for match 68841/72791
# Calculating OPR for match 68842/72791
# Calculating OPR for match 68843/72791
# Calculating OPR for match 68844/72791
# Calculating OPR for match 68845/72791
# Calculating OPR for match 68846/72791
# Calculating OPR for match 68847/72791
# Calculating OPR for match 68848/72791
# Calculating OPR for match 68849/72791
# Calculating OPR for match 68850/72791
# Calculating OPR for match 68851/72791
# Calculating OPR for match 68852/72791
# Calculating OPR for match 68853/72791
# Calculating OPR for match 68854/72791
# Calculating OPR for match 68855/72791
# Calculating OPR for match 68856/72791
# Calculating OPR for match 68857/72791
# Calculating OPR for match 68858/72791
# Calculating OPR for match 68859/72791
# Calculating OPR for match 68860/72791
# Calculating OPR for match 68861/72791
# Calculating OPR for match 68862/72791
# Calculating OPR for match 68863/72791
# Calculating OPR for match 68864/72791
# Calculating OPR for match 68865/72791
# Calculating OPR for match 68866/72791
# Calculating OPR for match 68867/72791
# Calculating OPR for match 68868/72791
# Calculating OPR for match 68869/72791
# Calculating OPR for match 68870/72791
# Calculating OPR for match 68871/72791
# Calculating OPR for match 68872/72791
# Calculating OPR for match 68873/72791
# Calculating OPR for match 68874/72791
# Calculating OPR for match 68875/72791
# Calculating OPR for match 68876/72791
# Calculating OPR for match 68877/72791
# Calculating OPR for match 68878/72791
# Calculating OPR for match 68879/72791
# Calculating OPR for match 68880/72791
# Calculating OPR for match 68881/72791
# Calculating OPR for match 68882/72791
# Calculating OPR for match 68883/72791
# Calculating OPR for match 68884/72791
# Calculating OPR for match 68885/72791
# Calculating OPR for match 68886/72791
# Calculating OPR for match 68887/72791
# Calculating OPR for match 68888/72791
# Calculating OPR for match 68889/72791
# Calculating OPR for match 68890/72791
# Calculating OPR for match 68891/72791
# Calculating OPR for match 68892/72791
# Calculating OPR for match 68893/72791
# Calculating OPR for match 68894/72791
# Calculating OPR for match 68895/72791
# Calculating OPR for match 68896/72791
# Calculating OPR for match 68897/72791
# Calculating OPR for match 68898/72791
# Calculating OPR for match 68899/72791
# Calculating OPR for match 68900/72791
# Calculating OPR for match 68901/72791
# Calculating OPR for match 68902/72791
# Calculating OPR for match 68903/72791
# Calculating OPR for match 68904/72791
# Calculating OPR for match 68905/72791
# Calculating OPR for match 68906/72791
# Calculating OPR for match 68907/72791
# Calculating OPR for match 68908/72791
# Calculating OPR for match 68909/72791
# Calculating OPR for match 68910/72791
# Calculating OPR for match 68911/72791
# Calculating OPR for match 68912/72791
# Calculating OPR for match 68913/72791
# Calculating OPR for match 68914/72791
# Calculating OPR for match 68915/72791
# Calculating OPR for match 68916/72791
# Calculating OPR for match 68917/72791
# Calculating OPR for match 68918/72791
# Calculating OPR for match 68919/72791
# Calculating OPR for match 68920/72791
# Calculating OPR for match 68921/72791
# Calculating OPR for match 68922/72791
# Calculating OPR for match 68923/72791
# Calculating OPR for match 68924/72791
# Calculating OPR for match 68925/72791
# Calculating OPR for match 68926/72791
# Calculating OPR for match 68927/72791
# Calculating OPR for match 68928/72791
# Calculating OPR for match 68929/72791
# Calculating OPR for match 68930/72791
# Calculating OPR for match 68931/72791
# Calculating OPR for match 68932/72791
# Calculating OPR for match 68933/72791
# Calculating OPR for match 68934/72791
# Calculating OPR for match 68935/72791
# Calculating OPR for match 68936/72791
# Calculating OPR for match 68937/72791
# Calculating OPR for match 68938/72791
# Calculating OPR for match 68939/72791
# Calculating OPR for match 68940/72791
# Calculating OPR for match 68941/72791
# Calculating OPR for match 68942/72791
# Calculating OPR for match 68943/72791
# Calculating OPR for match 68944/72791
# Calculating OPR for match 68945/72791
# Calculating OPR for match 68946/72791
# Calculating OPR for match 68947/72791
# Calculating OPR for match 68948/72791
# Calculating OPR for match 68949/72791
# Calculating OPR for match 68950/72791
# Calculating OPR for match 68951/72791
# Calculating OPR for match 68952/72791
# Calculating OPR for match 68953/72791
# Calculating OPR for match 68954/72791
# Calculating OPR for match 68955/72791
# Calculating OPR for match 68956/72791
# Calculating OPR for match 68957/72791
# Calculating OPR for match 68958/72791
# Calculating OPR for match 68959/72791
# Calculating OPR for match 68960/72791
# Calculating OPR for match 68961/72791
# Calculating OPR for match 68962/72791
# Calculating OPR for match 68963/72791
# Calculating OPR for match 68964/72791
# Calculating OPR for match 68965/72791
# Calculating OPR for match 68966/72791
# Calculating OPR for match 68967/72791
# Calculating OPR for match 68968/72791
# Calculating OPR for match 68969/72791
# Calculating OPR for match 68970/72791
# Calculating OPR for match 68971/72791
# Calculating OPR for match 68972/72791
# Calculating OPR for match 68973/72791
# Calculating OPR for match 68974/72791
# Calculating OPR for match 68975/72791
# Calculating OPR for match 68976/72791
# Calculating OPR for match 68977/72791
# Calculating OPR for match 68978/72791
# Calculating OPR for match 68979/72791
# Calculating OPR for match 68980/72791
# Calculating OPR for match 68981/72791
# Calculating OPR for match 68982/72791
# Calculating OPR for match 68983/72791
# Calculating OPR for match 68984/72791
# Calculating OPR for match 68985/72791
# Calculating OPR for match 68986/72791
# Calculating OPR for match 68987/72791
# Calculating OPR for match 68988/72791
# Calculating OPR for match 68989/72791
# Calculating OPR for match 68990/72791
# Calculating OPR for match 68991/72791
# Calculating OPR for match 68992/72791
# Calculating OPR for match 68993/72791
# Calculating OPR for match 68994/72791
# Calculating OPR for match 68995/72791
# Calculating OPR for match 68996/72791
# Calculating OPR for match 68997/72791
# Calculating OPR for match 68998/72791
# Calculating OPR for match 68999/72791
# Calculating OPR for match 69000/72791
# Calculating OPR for match 69001/72791
# Calculating OPR for match 69002/72791
# Calculating OPR for match 69003/72791
# Calculating OPR for match 69004/72791
# Calculating OPR for match 69005/72791
# Calculating OPR for match 69006/72791
# Calculating OPR for match 69007/72791
# Calculating OPR for match 69008/72791
# Calculating OPR for match 69009/72791
# Calculating OPR for match 69010/72791
# Calculating OPR for match 69011/72791
# Calculating OPR for match 69012/72791
# Calculating OPR for match 69013/72791
# Calculating OPR for match 69014/72791
# Calculating OPR for match 69015/72791
# Calculating OPR for match 69016/72791
# Calculating OPR for match 69017/72791
# Calculating OPR for match 69018/72791
# Calculating OPR for match 69019/72791
# Calculating OPR for match 69020/72791
# Calculating OPR for match 69021/72791
# Calculating OPR for match 69022/72791
# Calculating OPR for match 69023/72791
# Calculating OPR for match 69024/72791
# Calculating OPR for match 69025/72791
# Calculating OPR for match 69026/72791
# Calculating OPR for match 69027/72791
# Calculating OPR for match 69028/72791
# Calculating OPR for match 69029/72791
# Calculating OPR for match 69030/72791
# Calculating OPR for match 69031/72791
# Calculating OPR for match 69032/72791
# Calculating OPR for match 69033/72791
# Calculating OPR for match 69034/72791
# Calculating OPR for match 69035/72791
# Calculating OPR for match 69036/72791
# Calculating OPR for match 69037/72791
# Calculating OPR for match 69038/72791
# Calculating OPR for match 69039/72791
# Calculating OPR for match 69040/72791
# Calculating OPR for match 69041/72791
# Calculating OPR for match 69042/72791
# Calculating OPR for match 69043/72791
# Calculating OPR for match 69044/72791
# Calculating OPR for match 69045/72791
# Calculating OPR for match 69046/72791
# Calculating OPR for match 69047/72791
# Calculating OPR for match 69048/72791
# Calculating OPR for match 69049/72791
# Calculating OPR for match 69050/72791
# Calculating OPR for match 69051/72791
# Calculating OPR for match 69052/72791
# Calculating OPR for match 69053/72791
# ...
# Calculating OPR for match 72371/72791
# Calculating OPR for match 72372/72791
# Calculating OPR for match 72373/72791
# Calculating OPR for match 72374/72791
# Calculating OPR for match 72375/72791
# Calculating OPR for match 72376/72791
# Calculating OPR for match 72377/72791
# Calculating OPR for match 72378/72791
# Calculating OPR for match 72379/72791
# Calculating OPR for match 72380/72791
# Calculating OPR for match 72381/72791
# Calculating OPR for match 72382/72791
# Calculating OPR for match 72383/72791
# Calculating OPR for match 72384/72791
# Calculating OPR for match 72385/72791
# Calculating OPR for match 72386/72791
# Calculating OPR for match 72387/72791
# Calculating OPR for match 72388/72791
# Calculating OPR for match 72389/72791
# Calculating OPR for match 72390/72791
# Calculating OPR for match 72391/72791
# Calculating OPR for match 72392/72791
# Calculating OPR for match 72393/72791
# Calculating OPR for match 72394/72791
# Calculating OPR for match 72395/72791
# Calculating OPR for match 72396/72791
# Calculating OPR for match 72397/72791
# Calculating OPR for match 72398/72791
# Calculating OPR for match 72399/72791
# Calculating OPR for match 72400/72791
# Calculating OPR for match 72401/72791
# Calculating OPR for match 72402/72791
# Calculating OPR for match 72403/72791
# Calculating OPR for match 72404/72791
# Calculating OPR for match 72405/72791
# Calculating OPR for match 72406/72791
# Calculating OPR for match 72407/72791
# Calculating OPR for match 72408/72791
# Calculating OPR for match 72409/72791
# Calculating OPR for match 72410/72791
# Calculating OPR for match 72411/72791
# Calculating OPR for match 72412/72791
# Calculating OPR for match 72413/72791
# Calculating OPR for match 72414/72791
# Calculating OPR for match 72415/72791
# Calculating OPR for match 72416/72791
# Calculating OPR for match 72417/72791
# Calculating OPR for match 72418/72791
# Calculating OPR for match 72419/72791
# Calculating OPR for match 72420/72791
# Calculating OPR for match 72421/72791
# Calculating OPR for match 72422/72791
# Calculating OPR for match 72423/72791
# Calculating OPR for match 72424/72791
# Calculating OPR for match 72425/72791
# Calculating OPR for match 72426/72791
# Calculating OPR for match 72427/72791
# Calculating OPR for match 72428/72791
# Calculating OPR for match 72429/72791
# Calculating OPR for match 72430/72791
# Calculating OPR for match 72431/72791
# Calculating OPR for match 72432/72791
# Calculating OPR for match 72433/72791
# Calculating OPR for match 72434/72791
# Calculating OPR for match 72435/72791
# Calculating OPR for match 72436/72791
# Calculating OPR for match 72437/72791
# Calculating OPR for match 72438/72791
# Calculating OPR for match 72439/72791
# Calculating OPR for match 72440/72791
# Calculating OPR for match 72441/72791
# Calculating OPR for match 72442/72791
# Calculating OPR for match 72443/72791
# Calculating OPR for match 72444/72791
# Calculating OPR for match 72445/72791
# Calculating OPR for match 72446/72791
# Calculating OPR for match 72447/72791
# Calculating OPR for match 72448/72791
# Calculating OPR for match 72449/72791
# Calculating OPR for match 72450/72791
# Calculating OPR for match 72451/72791
# Calculating OPR for match 72452/72791
# Calculating OPR for match 72453/72791
# Calculating OPR for match 72454/72791
# Calculating OPR for match 72455/72791
# Calculating OPR for match 72456/72791
# Calculating OPR for match 72457/72791
# Calculating OPR for match 72458/72791
# Calculating OPR for match 72459/72791
# Calculating OPR for match 72460/72791
# Calculating OPR for match 72461/72791
# Calculating OPR for match 72462/72791
# Calculating OPR for match 72463/72791
# Calculating OPR for match 72464/72791
# Calculating OPR for match 72465/72791
# Calculating OPR for match 72466/72791
# Calculating OPR for match 72467/72791
# Calculating OPR for match 72468/72791
# Calculating OPR for match 72469/72791
# Calculating OPR for match 72470/72791
# Calculating OPR for match 72471/72791
# Calculating OPR for match 72472/72791
# Calculating OPR for match 72473/72791
# Calculating OPR for match 72474/72791
# Calculating OPR for match 72475/72791
# Calculating OPR for match 72476/72791
# Calculating OPR for match 72477/72791
# Calculating OPR for match 72478/72791
# Calculating OPR for match 72479/72791
# Calculating OPR for match 72480/72791
# Calculating OPR for match 72481/72791
# Calculating OPR for match 72482/72791
# Calculating OPR for match 72483/72791
# Calculating OPR for match 72484/72791
# Calculating OPR for match 72485/72791
# Calculating OPR for match 72486/72791
# Calculating OPR for match 72487/72791
# Calculating OPR for match 72488/72791
# Calculating OPR for match 72489/72791
# Calculating OPR for match 72490/72791
# Calculating OPR for match 72491/72791
# Calculating OPR for match 72492/72791
# Calculating OPR for match 72493/72791
# Calculating OPR for match 72494/72791
# Calculating OPR for match 72495/72791
# Calculating OPR for match 72496/72791
# Calculating OPR for match 72497/72791
# Calculating OPR for match 72498/72791
# Calculating OPR for match 72499/72791
# Calculating OPR for match 72500/72791
# Calculating OPR for match 72501/72791
# Calculating OPR for match 72502/72791
# Calculating OPR for match 72503/72791
# Calculating OPR for match 72504/72791
# Calculating OPR for match 72505/72791
# Calculating OPR for match 72506/72791
# Calculating OPR for match 72507/72791
# Calculating OPR for match 72508/72791
# Calculating OPR for match 72509/72791
# Calculating OPR for match 72510/72791
# Calculating OPR for match 72511/72791
# Calculating OPR for match 72512/72791
# Calculating OPR for match 72513/72791
# Calculating OPR for match 72514/72791
# Calculating OPR for match 72515/72791
# Calculating OPR for match 72516/72791
# Calculating OPR for match 72517/72791
# Calculating OPR for match 72518/72791
# Calculating OPR for match 72519/72791
# Calculating OPR for match 72520/72791
# Calculating OPR for match 72521/72791
# Calculating OPR for match 72522/72791
# Calculating OPR for match 72523/72791
# Calculating OPR for match 72524/72791
# Calculating OPR for match 72525/72791
# Calculating OPR for match 72526/72791
# Calculating OPR for match 72527/72791
# Calculating OPR for match 72528/72791
# Calculating OPR for match 72529/72791
# Calculating OPR for match 72530/72791
# Calculating OPR for match 72531/72791
# Calculating OPR for match 72532/72791
# Calculating OPR for match 72533/72791
# Calculating OPR for match 72534/72791
# Calculating OPR for match 72535/72791
# Calculating OPR for match 72536/72791
# Calculating OPR for match 72537/72791
# Calculating OPR for match 72538/72791
# Calculating OPR for match 72539/72791
# Calculating OPR for match 72540/72791
# Calculating OPR for match 72541/72791
# Calculating OPR for match 72542/72791
# Calculating OPR for match 72543/72791
# Calculating OPR for match 72544/72791
# Calculating OPR for match 72545/72791
# Calculating OPR for match 72546/72791
# Calculating OPR for match 72547/72791
# Calculating OPR for match 72548/72791
# Calculating OPR for match 72549/72791
# Calculating OPR for match 72550/72791
# Calculating OPR for match 72551/72791
# Calculating OPR for match 72552/72791
# Calculating OPR for match 72553/72791
# Calculating OPR for match 72554/72791
# Calculating OPR for match 72555/72791
# Calculating OPR for match 72556/72791
# Calculating OPR for match 72557/72791
# Calculating OPR for match 72558/72791
# Calculating OPR for match 72559/72791
# Calculating OPR for match 72560/72791
# Calculating OPR for match 72561/72791
# Calculating OPR for match 72562/72791
# Calculating OPR for match 72563/72791
# Calculating OPR for match 72564/72791
# Calculating OPR for match 72565/72791
# Calculating OPR for match 72566/72791
# Calculating OPR for match 72567/72791
# Calculating OPR for match 72568/72791
# Calculating OPR for match 72569/72791
# Calculating OPR for match 72570/72791
# Calculating OPR for match 72571/72791
# Calculating OPR for match 72572/72791
# Calculating OPR for match 72573/72791
# Calculating OPR for match 72574/72791
# Calculating OPR for match 72575/72791
# Calculating OPR for match 72576/72791
# Calculating OPR for match 72577/72791
# Calculating OPR for match 72578/72791
# Calculating OPR for match 72579/72791
# Calculating OPR for match 72580/72791
# Calculating OPR for match 72581/72791
# Calculating OPR for match 72582/72791
# Calculating OPR for match 72583/72791
# Calculating OPR for match 72584/72791
# Calculating OPR for match 72585/72791
# Calculating OPR for match 72586/72791
# Calculating OPR for match 72587/72791
# Calculating OPR for match 72588/72791
# Calculating OPR for match 72589/72791
# Calculating OPR for match 72590/72791
# Calculating OPR for match 72591/72791
# Calculating OPR for match 72592/72791
# Calculating OPR for match 72593/72791
# Calculating OPR for match 72594/72791
# Calculating OPR for match 72595/72791
# Calculating OPR for match 72596/72791
# Calculating OPR for match 72597/72791
# Calculating OPR for match 72598/72791
# Calculating OPR for match 72599/72791
# Calculating OPR for match 72600/72791
# Calculating OPR for match 72601/72791
# Calculating OPR for match 72602/72791
# Calculating OPR for match 72603/72791
# Calculating OPR for match 72604/72791
# Calculating OPR for match 72605/72791
# Calculating OPR for match 72606/72791
# Calculating OPR for match 72607/72791
# Calculating OPR for match 72608/72791
# Calculating OPR for match 72609/72791
# Calculating OPR for match 72610/72791
# Calculating OPR for match 72611/72791
# Calculating OPR for match 72612/72791
# Calculating OPR for match 72613/72791
# Calculating OPR for match 72614/72791
# Calculating OPR for match 72615/72791
# Calculating OPR for match 72616/72791
# Calculating OPR for match 72617/72791
# Calculating OPR for match 72618/72791
# Calculating OPR for match 72619/72791
# Calculating OPR for match 72620/72791
# Calculating OPR for match 72621/72791
# Calculating OPR for match 72622/72791
# Calculating OPR for match 72623/72791
# Calculating OPR for match 72624/72791
# Calculating OPR for match 72625/72791
# Calculating OPR for match 72626/72791
# Calculating OPR for match 72627/72791
# Calculating OPR for match 72628/72791
# Calculating OPR for match 72629/72791
# Calculating OPR for match 72630/72791
# Calculating OPR for match 72631/72791
# Calculating OPR for match 72632/72791
# Calculating OPR for match 72633/72791
# Calculating OPR for match 72634/72791
# Calculating OPR for match 72635/72791
# Calculating OPR for match 72636/72791
# Calculating OPR for match 72637/72791
# Calculating OPR for match 72638/72791
# Calculating OPR for match 72639/72791
# Calculating OPR for match 72640/72791
# Calculating OPR for match 72641/72791
# Calculating OPR for match 72642/72791
# Calculating OPR for match 72643/72791
# Calculating OPR for match 72644/72791
# Calculating OPR for match 72645/72791
# Calculating OPR for match 72646/72791
# Calculating OPR for match 72647/72791
# Calculating OPR for match 72648/72791
# Calculating OPR for match 72649/72791
# Calculating OPR for match 72650/72791
# Calculating OPR for match 72651/72791
# Calculating OPR for match 72652/72791
# Calculating OPR for match 72653/72791
# Calculating OPR for match 72654/72791
# Calculating OPR for match 72655/72791
# Calculating OPR for match 72656/72791
# Calculating OPR for match 72657/72791
# Calculating OPR for match 72658/72791
# Calculating OPR for match 72659/72791
# Calculating OPR for match 72660/72791
# Calculating OPR for match 72661/72791
# Calculating OPR for match 72662/72791
# Calculating OPR for match 72663/72791
# Calculating OPR for match 72664/72791
# Calculating OPR for match 72665/72791
# Calculating OPR for match 72666/72791
# Calculating OPR for match 72667/72791
# Calculating OPR for match 72668/72791
# Calculating OPR for match 72669/72791
# Calculating OPR for match 72670/72791
# Calculating OPR for match 72671/72791
# Calculating OPR for match 72672/72791
# Calculating OPR for match 72673/72791
# Calculating OPR for match 72674/72791
# Calculating OPR for match 72675/72791
# Calculating OPR for match 72676/72791
# Calculating OPR for match 72677/72791
# Calculating OPR for match 72678/72791
# Calculating OPR for match 72679/72791
# Calculating OPR for match 72680/72791
# Calculating OPR for match 72681/72791
# Calculating OPR for match 72682/72791
# Calculating OPR for match 72683/72791
# Calculating OPR for match 72684/72791
# Calculating OPR for match 72685/72791
# Calculating OPR for match 72686/72791
# Calculating OPR for match 72687/72791
# Calculating OPR for match 72688/72791
# Calculating OPR for match 72689/72791
# Calculating OPR for match 72690/72791
# Calculating OPR for match 72691/72791
# Calculating OPR for match 72692/72791
# Calculating OPR for match 72693/72791
# Calculating OPR for match 72694/72791
# Calculating OPR for match 72695/72791
# Calculating OPR for match 72696/72791
# Calculating OPR for match 72697/72791
# Calculating OPR for match 72698/72791
# Calculating OPR for match 72699/72791
# Calculating OPR for match 72700/72791
# Calculating OPR for match 72701/72791
# Calculating OPR for match 72702/72791
# Calculating OPR for match 72703/72791
# Calculating OPR for match 72704/72791
# Calculating OPR for match 72705/72791
# Calculating OPR for match 72706/72791
# Calculating OPR for match 72707/72791
# Calculating OPR for match 72708/72791
# Calculating OPR for match 72709/72791
# Calculating OPR for match 72710/72791
# Calculating OPR for match 72711/72791
# Calculating OPR for match 72712/72791
# Calculating OPR for match 72713/72791
# Calculating OPR for match 72714/72791
# Calculating OPR for match 72715/72791
# Calculating OPR for match 72716/72791
# Calculating OPR for match 72717/72791
# Calculating OPR for match 72718/72791
# Calculating OPR for match 72719/72791
# Calculating OPR for match 72720/72791
# Calculating OPR for match 72721/72791
# Calculating OPR for match 72722/72791
# Calculating OPR for match 72723/72791
# Calculating OPR for match 72724/72791
# Calculating OPR for match 72725/72791
# Calculating OPR for match 72726/72791
# Calculating OPR for match 72727/72791
# Calculating OPR for match 72728/72791
# Calculating OPR for match 72729/72791
# Calculating OPR for match 72730/72791
# Calculating OPR for match 72731/72791
# Calculating OPR for match 72732/72791
# Calculating OPR for match 72733/72791
# Calculating OPR for match 72734/72791
# Calculating OPR for match 72735/72791
# Calculating OPR for match 72736/72791
# Calculating OPR for match 72737/72791
# Calculating OPR for match 72738/72791
# Calculating OPR for match 72739/72791
# Calculating OPR for match 72740/72791
# Calculating OPR for match 72741/72791
# Calculating OPR for match 72742/72791
# Calculating OPR for match 72743/72791
# Calculating OPR for match 72744/72791
# Calculating OPR for match 72745/72791
# Calculating OPR for match 72746/72791
# Calculating OPR for match 72747/72791
# Calculating OPR for match 72748/72791
# Calculating OPR for match 72749/72791
# Calculating OPR for match 72750/72791
# Calculating OPR for match 72751/72791
# Calculating OPR for match 72752/72791
# Calculating OPR for match 72753/72791
# Calculating OPR for match 72754/72791
# Calculating OPR for match 72755/72791
# Calculating OPR for match 72756/72791
# Calculating OPR for match 72757/72791
# Calculating OPR for match 72758/72791
# Calculating OPR for match 72759/72791
# Calculating OPR for match 72760/72791
# Calculating OPR for match 72761/72791
# Calculating OPR for match 72762/72791
# Calculating OPR for match 72763/72791
# Calculating OPR for match 72764/72791
# Calculating OPR for match 72765/72791
# Calculating OPR for match 72766/72791
# Calculating OPR for match 72767/72791
# Calculating OPR for match 72768/72791
# Calculating OPR for match 72769/72791
# Calculating OPR for match 72770/72791
# Calculating OPR for match 72771/72791
# Calculating OPR for match 72772/72791
# Calculating OPR for match 72773/72791
# Calculating OPR for match 72774/72791
# Calculating OPR for match 72775/72791
# Calculating OPR for match 72776/72791
# Calculating OPR for match 72777/72791
# Calculating OPR for match 72778/72791
# Calculating OPR for match 72779/72791
# Calculating OPR for match 72780/72791
# Calculating OPR for match 72781/72791
# Calculating OPR for match 72782/72791
# Calculating OPR for match 72783/72791
# Calculating OPR for match 72784/72791
# Calculating OPR for match 72785/72791
# Calculating OPR for match 72786/72791
# Calculating OPR for match 72787/72791
# Calculating OPR for match 72788/72791
# Calculating OPR for match 72789/72791
# Calculating OPR for match 72790/72791
# Calculating OPR for match 72791/72791

# %% [markdown]
# ## 4. Creating the Use Case CSV

# %% [markdown]
# Now that we have engineered all of our features it is time to save it to a csv so that we can use it in **FRC Match Simulator.ipynb**. There we will look more into the features we just engineered and we will construct our models.

# %%
#Get the use case dataframe and create a csv
use_case_df = match_df
use_case_df.to_csv('frc_use_case.csv')

# %% [markdown]
# ## 5. Final Thoughts

# %% [markdown]
# If you have made it this far then I thank you for taking the time to read the whole thing. Due to the nature of FIRST Robotics we had to make a lot of assumptions with our features as well as construct them in interesting ways. If you want to know more about FIRST Robotics and why a model can be useful for teams as well as the result of our feature engineering I would encourage you to checkout the **FRC Match Simulator.ipynb** file which should be in the same repo as this one.

# %%
print(match_df)
# Out:
#        red_score    red_0    red_1  ... red_opr  blue_opr opr_ratio
# 0             66   frc157   frc166  ...     NaN       NaN   1.00000
# 1             50  frc1519    frc58  ...     NaN       NaN   1.00000
# 2             62    frc78   frc319  ...     NaN       NaN   1.00000
# 3             66   frc811   frc509  ...     NaN       NaN   1.00000
# 4             24   frc157  frc1735  ...     NaN       NaN   1.00000
# ...          ...      ...      ...  ...     ...       ...       ...
# 72786         88  frc6025  frc6417  ...   122.0     133.0   0.99989
# 72787        151  frc6989  frc7296  ...   136.0     133.0   1.00003
# 72788         42  frc6989  frc7296  ...   136.0     131.0   1.00005
# 72789        143  frc6989  frc7296  ...   163.0     131.0   1.00032
# 72790         45  frc6989  frc7296  ...   158.0     129.0   1.00029
#
# [72791 rows x 47 columns]
